# %% [markdown]
# # 2RP Net - Teste para Data Engineer
# ### Desafio:
# ### - 2.	Realize a extração dos dados dos 3 ultimos meses de prescrição

# %%
# Para essa parte do desafio escolheu-se trabalhar com o consumo de API
# Para tanto, foi utilizado como Linguagem padrão o Python - Jupyter e como Banco de Dados o MongoDB
# Já para o consumo da API em si, foi necessário a utilização das bibliotecas:
# Requests - Para solicitações HTTP
# json - Para trabalhar com arquivos JSON
# pymongo - Para realizar a conexão entre o Python e o Banco de Dados o MongoDB
# bson.son.- Usado principalmente no pymongo, o qual será importante na persistência e tratamento dos dados

import json
import requests
from pymongo import MongoClient
from ast import main
from bson.son import SON

# %%
#Funções em Python
#Função criada para inserir os dados

def inserir_dados(client, collection, dados):
    collection.insert_many(dados)
    client.close()
    print("Dados Inseridos com Sucesso")

# %%
#Função elaborada para a criação do banco de dado contendo o database e a collection a ser trabalhado

def criar_banco(dados, nome_tabela):
    client = MongoClient('localhost', 27017)
    db = client['banco']
    collection = db[nome_tabela]
    inserir_dados(client, collection, dados)

# %%
# Como o desafio pede para separar os dados entre prescribers e prescriptions
# Foi criado uma função para consumo e armazenamento dos dados para cada situação
# Aqui temos o consumo da API - prescribers (Prescritores)
# Sendo estabelecida a condição do desafio "extração dos dados dos 3 ultimos meses"
# Como o enunciado possibiltou o trabalho com API limitando a quantidade, 
# Escolheu-se o intervalo de 10mil linhas de coletas da API prescribers
# De um "total": 17621811 para o mês 08
# De um "total": 17604125 para o mês 07
# De um "total": 17603900 para o mês 06

def requisicao_epd():
    for mes in range(8, 5, -1):
        api = requests.get(f'https://opendata.nhsbsa.net/api/3/action/datastore_search?resource_id=EPD_20220{mes}&limit=10000'.format(mes))
        dados = api.json()['result']['records']
        criar_banco(dados, 'tabela1')

# %%
# Aqui temos o consumo da API -  prescriptions (prescrições)
# Aqui escolhe-se trablhar com um função que realiza a extração dos dados dos 3 ultimos anos"
# Como o enunciado possibiltou o trabalho com API limitando a sua quantidade, 
# Escolheu-se o intervalo de 10mil linhas de coletas da API prescriptions
# De um "total": 752697 para o ano de 2021
# De um "total": 768231 para o ano de 2020
# De um "total": 802855 para o ano de 2019

def requisicao_pca():
    for ano in range(20, 17, -1):
        api = requests.get(f'https://opendata.nhsbsa.net/api/3/action/datastore_search?resource_id=PCA_STP_SNOMED_20{ano}&limit=10000'.format(ano))
        dados = api.json()['result']['records']
        criar_banco(dados, 'tabela2')

# %%
if __name__ == '__main__':
    print("")
    print("Inserção dos dados - Prescrições")
    requisicao_pca()
    
    print("")
    print("Inserção dos dados - Prescritores")
    requisicao_epd()
    
    print("")
    print("Processo Finalizado com Sucesso\n")
# Out:
# Inserção dos dados - Prescrições
# Dados Inseridos com Sucesso
# Dados Inseridos com Sucesso
# Dados Inseridos com Sucesso
#
# Inserção dos dados - Prescritores
# Dados Inseridos com Sucesso
# Dados Inseridos com Sucesso
# Dados Inseridos com Sucesso
#
# Processo Finalizado com Sucesso

# %% [markdown]
# ### 6 - Gere scripts que atendam as solicitações abaixo:
#
# #### - Para a realização dessa etapa do desavio, foi imprescindívell a utilização  do "Studio 3T for MongoDB", o qual além de facilitar a visualização da conexão com o banco Mongo, possibilitou a transposição de uma linguagem SQL ou NoSQL para comandos Python.

# %%
# A) Crie um dataframe contendo os 10 principais produtos químicos prescritos por região.

from bson.son import SON
from pymongo import MongoClient


#Realizando a conexão com o banco
client = MongoClient('localhost', 27017)
database = client["banco"]
collection = database["tabela2"]

#Lista contendo o nome de todas as regiões
lista = ['SOUTH EAST','MIDLANDS AND EAST OF ENGLAND (C 01-Apr-20)',
         'SOUTH OF ENGLAND (C 01-Apr-20)', 'SOUTH WEST', 'MIDLANDS', 
         'LONDON', 'NORTH EAST AND YORKSHIRE' ,'NORTH WEST', 'EAST OF ENGLAND' ]

for i in range(len(lista)):
    pipeline = [
        {
            u"$match": {
                u"REGION_NAME": lista[i]
            }
        }, 
        {
            u"$group": {
                u"_id": {
                    u"BNF_SECTION": u"$BNF_SECTION"
                },
                u"COUNT(BNF_SECTION)": {
                    u"$sum": 1
                }
            }
        }, 
        {
            u"$project": {
                u"COUNT(BNF_SECTION)": u"$COUNT(BNF_SECTION)",
                u"BNF_SECTION": u"$_id.BNF_SECTION",
                u"_id": 0
            }
        }, 
        {
            u"$sort": SON([ (u"COUNT(BNF_SECTION)", -1) ])
        }, 
        {
            u"$limit": 10
        }
    ]

    cursor = collection.aggregate(
        pipeline, 
        allowDiskUse = True
    )
    
    print("")
    print(lista[i])
    print("")
    
    for doc in cursor:

        print(doc)

    
        
client.close()
# Out:
# SOUTH EAST
#
# {'COUNT(BNF_SECTION)': 857, 'BNF_SECTION': 'Beta-adrenoceptor blocking drugs'}
# {'COUNT(BNF_SECTION)': 728, 'BNF_SECTION': 'Hypertension and heart failure'}
# {'COUNT(BNF_SECTION)': 721, 'BNF_SECTION': 'Antisecretory drugs and mucosal protectants'}
# {'COUNT(BNF_SECTION)': 583, 'BNF_SECTION': 'Diuretics'}
# {'COUNT(BNF_SECTION)': 459, 'BNF_SECTION': 'Laxatives'}
# {'COUNT(BNF_SECTION)': 286, 'BNF_SECTION': 'Antispasmodics and other drugs altering gut motility'}
# {'COUNT(BNF_SECTION)': 210, 'BNF_SECTION': 'Chronic bowel disorders'}
# {'COUNT(BNF_SECTION)': 162, 'BNF_SECTION': 'Anti-arrhythmic drugs'}
# {'COUNT(BNF_SECTION)': 85, 'BNF_SECTION': 'Dyspepsia and gastro-oesophageal reflux disease'}
# {'COUNT(BNF_SECTION)': 54, 'BNF_SECTION': 'Drugs affecting intestinal secretions'}
#
# MIDLANDS AND EAST OF ENGLAND (C 01-Apr-20)
#
# {'COUNT(BNF_SECTION)': 41, 'BNF_SECTION': 'Beta-adrenoceptor blocking drugs'}
# {'COUNT(BNF_SECTION)': 39, 'BNF_SECTION': 'Antisecretory drugs and mucosal protectants'}
# {'COUNT(BNF_SECTION)': 19, 'BNF_SECTION': 'Diuretics'}
# {'COUNT(BNF_SECTION)': 18, 'BNF_SECTION': 'Laxatives'}
# {'COUNT(BNF_SECTION)': 11, 'BNF_SECTION': 'Hypertension and heart failure'}
# {'COUNT(BNF_SECTION)': 7, 'BNF_SECTION': 'Anti-arrhythmic drugs'}
# {'COUNT(BNF_SECTION)': 6, 'BNF_SECTION': 'Antispasmodics and other drugs altering gut motility'}
# {'COUNT(BNF_SECTION)': 6, 'BNF_SECTION': 'Positive inotropic drugs'}
# {'COUNT(BNF_SECTION)': 4, 'BNF_SECTION': 'Chronic bowel disorders'}
# {'COUNT(BNF_SECTION)': 3, 'BNF_SECTION': 'Local preparations for anal and rectal disorders'}
#
# SOUTH OF ENGLAND (C 01-Apr-20)
#
# {'COUNT(BNF_SECTION)': 35, 'BNF_SECTION': 'Beta-adrenoceptor blocking drugs'}
# {'COUNT(BNF_SECTION)': 31, 'BNF_SECTION': 'Antisecretory drugs and mucosal protectants'}
# {'COUNT(BNF_SECTION)': 23, 'BNF_SECTION': 'Diuretics'}
# {'COUNT(BNF_SECTION)': 13, 'BNF_SECTION': 'Laxatives'}
# {'COUNT(BNF_SECTION)': 11, 'BNF_SECTION': 'Hypertension and heart failure'}
# {'COUNT(BNF_SECTION)': 6, 'BNF_SECTION': 'Antispasmodics and other drugs altering gut motility'}
# {'COUNT(BNF_SECTION)': 4, 'BNF_SECTION': 'Positive inotropic drugs'}
# {'COUNT(BNF_SECTION)': 3, 'BNF_SECTION': 'Anti-arrhythmic drugs'}
# {'COUNT(BNF_SECTION)': 3, 'BNF_SECTION': 'Local preparations for anal and rectal disorders'}
# {'COUNT(BNF_SECTION)': 3, 'BNF_SECTION': 'Chronic bowel disorders'}
#
# SOUTH WEST
#
# {'COUNT(BNF_SECTION)': 987, 'BNF_SECTION': 'Beta-adrenoceptor blocking drugs'}
# {'COUNT(BNF_SECTION)': 834, 'BNF_SECTION': 'Antisecretory drugs and mucosal protectants'}
# {'COUNT(BNF_SECTION)': 790, 'BNF_SECTION': 'Hypertension and heart failure'}
# {'COUNT(BNF_SECTION)': 665, 'BNF_SECTION': 'Diuretics'}
# {'COUNT(BNF_SECTION)': 534, 'BNF_SECTION': 'Laxatives'}
# {'COUNT(BNF_SECTION)': 300, 'BNF_SECTION': 'Antispasmodics and other drugs altering gut motility'}
# {'COUNT(BNF_SECTION)': 244, 'BNF_SECTION': 'Chronic bowel disorders'}
# {'COUNT(BNF_SECTION)': 186, 'BNF_SECTION': 'Anti-arrhythmic drugs'}
# {'COUNT(BNF_SECTION)': 98, 'BNF_SECTION': 'Dyspepsia and gastro-oesophageal reflux disease'}
# {'COUNT(BNF_SECTION)': 63, 'BNF_SECTION': 'Drugs affecting intestinal secretions'}
#
# MIDLANDS
#
# {'COUNT(BNF_SECTION)': 1537, 'BNF_SECTION': 'Beta-adrenoceptor blocking drugs'}
# {'COUNT(BNF_SECTION)': 1312, 'BNF_SECTION': 'Antisecretory drugs and mucosal protectants'}
# {'COUNT(BNF_SECTION)': 1293, 'BNF_SECTION': 'Hypertension and heart failure'}
# {'COUNT(BNF_SECTION)': 1047, 'BNF_SECTION': 'Diuretics'}
# {'COUNT(BNF_SECTION)': 839, 'BNF_SECTION': 'Laxatives'}
# {'COUNT(BNF_SECTION)': 514, 'BNF_SECTION': 'Antispasmodics and other drugs altering gut motility'}
# {'COUNT(BNF_SECTION)': 383, 'BNF_SECTION': 'Chronic bowel disorders'}
# {'COUNT(BNF_SECTION)': 296, 'BNF_SECTION': 'Anti-arrhythmic drugs'}
# {'COUNT(BNF_SECTION)': 151, 'BNF_SECTION': 'Dyspepsia and gastro-oesophageal reflux disease'}
# {'COUNT(BNF_SECTION)': 99, 'BNF_SECTION': 'Drugs affecting intestinal secretions'}
#
# LONDON
#
# {'COUNT(BNF_SECTION)': 708, 'BNF_SECTION': 'Beta-adrenoceptor blocking drugs'}
# {'COUNT(BNF_SECTION)': 607, 'BNF_SECTION': 'Hypertension and heart failure'}
# {'COUNT(BNF_SECTION)': 601, 'BNF_SECTION': 'Antisecretory drugs and mucosal protectants'}
# {'COUNT(BNF_SECTION)': 492, 'BNF_SECTION': 'Diuretics'}
# {'COUNT(BNF_SECTION)': 388, 'BNF_SECTION': 'Laxatives'}
# {'COUNT(BNF_SECTION)': 242, 'BNF_SECTION': 'Antispasmodics and other drugs altering gut motility'}
# {'COUNT(BNF_SECTION)': 175, 'BNF_SECTION': 'Chronic bowel disorders'}
# {'COUNT(BNF_SECTION)': 135, 'BNF_SECTION': 'Anti-arrhythmic drugs'}
# {'COUNT(BNF_SECTION)': 71, 'BNF_SECTION': 'Dyspepsia and gastro-oesophageal reflux disease'}
# {'COUNT(BNF_SECTION)': 45, 'BNF_SECTION': 'Positive inotropic drugs'}
#
# NORTH EAST AND YORKSHIRE
#
# {'COUNT(BNF_SECTION)': 571, 'BNF_SECTION': 'Beta-adrenoceptor blocking drugs'}
# {'COUNT(BNF_SECTION)': 485, 'BNF_SECTION': 'Hypertension and heart failure'}
# {'COUNT(BNF_SECTION)': 485, 'BNF_SECTION': 'Antisecretory drugs and mucosal protectants'}
# {'COUNT(BNF_SECTION)': 390, 'BNF_SECTION': 'Diuretics'}
# {'COUNT(BNF_SECTION)': 314, 'BNF_SECTION': 'Laxatives'}
# {'COUNT(BNF_SECTION)': 194, 'BNF_SECTION': 'Antispasmodics and other drugs altering gut motility'}
# {'COUNT(BNF_SECTION)': 140, 'BNF_SECTION': 'Chronic bowel disorders'}
# {'COUNT(BNF_SECTION)': 106, 'BNF_SECTION': 'Anti-arrhythmic drugs'}
# {'COUNT(BNF_SECTION)': 56, 'BNF_SECTION': 'Dyspepsia and gastro-oesophageal reflux disease'}
# {'COUNT(BNF_SECTION)': 36, 'BNF_SECTION': 'Positive inotropic drugs'}
#
# NORTH WEST
#
# {'COUNT(BNF_SECTION)': 427, 'BNF_SECTION': 'Beta-adrenoceptor blocking drugs'}
# {'COUNT(BNF_SECTION)': 365, 'BNF_SECTION': 'Hypertension and heart failure'}
# {'COUNT(BNF_SECTION)': 363, 'BNF_SECTION': 'Antisecretory drugs and mucosal protectants'}
# {'COUNT(BNF_SECTION)': 296, 'BNF_SECTION': 'Diuretics'}
# {'COUNT(BNF_SECTION)': 236, 'BNF_SECTION': 'Laxatives'}
# {'COUNT(BNF_SECTION)': 151, 'BNF_SECTION': 'Antispasmodics and other drugs altering gut motility'}
# {'COUNT(BNF_SECTION)': 105, 'BNF_SECTION': 'Chronic bowel disorders'}
# {'COUNT(BNF_SECTION)': 81, 'BNF_SECTION': 'Anti-arrhythmic drugs'}
# {'COUNT(BNF_SECTION)': 43, 'BNF_SECTION': 'Dyspepsia and gastro-oesophageal reflux disease'}
# {'COUNT(BNF_SECTION)': 28, 'BNF_SECTION': 'Drugs affecting intestinal secretions'}
#
# EAST OF ENGLAND
#
# {'COUNT(BNF_SECTION)': 841, 'BNF_SECTION': 'Beta-adrenoceptor blocking drugs'}
# {'COUNT(BNF_SECTION)': 729, 'BNF_SECTION': 'Antisecretory drugs and mucosal protectants'}
# {'COUNT(BNF_SECTION)': 701, 'BNF_SECTION': 'Hypertension and heart failure'}
# {'COUNT(BNF_SECTION)': 576, 'BNF_SECTION': 'Diuretics'}
# {'COUNT(BNF_SECTION)': 465, 'BNF_SECTION': 'Laxatives'}
# {'COUNT(BNF_SECTION)': 282, 'BNF_SECTION': 'Antispasmodics and other drugs altering gut motility'}
# {'COUNT(BNF_SECTION)': 210, 'BNF_SECTION': 'Chronic bowel disorders'}
# {'COUNT(BNF_SECTION)': 162, 'BNF_SECTION': 'Anti-arrhythmic drugs'}
# {'COUNT(BNF_SECTION)': 84, 'BNF_SECTION': 'Dyspepsia and gastro-oesophageal reflux disease'}
# {'COUNT(BNF_SECTION)': 54, 'BNF_SECTION': 'Positive inotropic drugs'}

# %%
# 6) B - Quais produtos químicos prescritos tiveram a maior somatória de custos por mês? Liste os 10 primeiros.
from bson.son import SON
from pymongo import MongoClient

#Realizando a conexão com o banco
client = MongoClient('localhost', 27017)
database = client["banco"]
collection = database["tabela1"]


#Lista contendo o nome dos meses a serem consultados 
lista = [202207, 202208, 202206]

for i in range(len(lista)):
    pipeline = [
    {
        u"$match": {
            u"YEAR_MONTH": (lista[i])
        }
    }, 
    {
        u"$group": {
            u"_id": {
                u"YEAR_MONTH": u"$YEAR_MONTH",
                u"ICB_CODE": u"$ICB_CODE"
            },
            u"SUM(ACTUAL_COST)": {
                u"$sum": u"$ACTUAL_COST"
            }
        }
    }, 
    {
        u"$project": {
            u"SUM(ACTUAL_COST)": u"$SUM(ACTUAL_COST)",
            u"YEAR_MONTH": u"$_id.YEAR_MONTH",
            u"_id": 0
        }
    }, 
    {
        u"$sort": SON([ (u"YEAR_MONTH", 1) ])
    }, 
    {
        u"$limit": 10
    }
    ]

    cursor = collection.aggregate(
        pipeline, 
        allowDiskUse = True
    )
    
    print("")
    print(lista[i])
    print("")
    
    for doc in cursor:
        print(doc)

    
        
client.close()
# Out:
# 202207
#
# {'SUM(ACTUAL_COST)': 82951.40002, 'YEAR_MONTH': 202207}
# {'SUM(ACTUAL_COST)': 7737.28457, 'YEAR_MONTH': 202207}
# {'SUM(ACTUAL_COST)': 122437.12867, 'YEAR_MONTH': 202207}
# {'SUM(ACTUAL_COST)': 227634.22391, 'YEAR_MONTH': 202207}
#
# 202208
#
# {'SUM(ACTUAL_COST)': 3755.48009, 'YEAR_MONTH': 202208}
# {'SUM(ACTUAL_COST)': 663.08682, 'YEAR_MONTH': 202208}
# {'SUM(ACTUAL_COST)': 7106.92411, 'YEAR_MONTH': 202208}
# {'SUM(ACTUAL_COST)': 579.9309, 'YEAR_MONTH': 202208}
# {'SUM(ACTUAL_COST)': 1481.97098, 'YEAR_MONTH': 202208}
# {'SUM(ACTUAL_COST)': 1023.38472, 'YEAR_MONTH': 202208}
# {'SUM(ACTUAL_COST)': 130.98767999999998, 'YEAR_MONTH': 202208}
# {'SUM(ACTUAL_COST)': 430.36577, 'YEAR_MONTH': 202208}
# {'SUM(ACTUAL_COST)': 103464.53441, 'YEAR_MONTH': 202208}
# {'SUM(ACTUAL_COST)': 650.35332, 'YEAR_MONTH': 202208}
#
# 202206
#
# {'SUM(ACTUAL_COST)': 9920.18462, 'YEAR_MONTH': 202206}
# {'SUM(ACTUAL_COST)': 39.80944, 'YEAR_MONTH': 202206}
# {'SUM(ACTUAL_COST)': 1127.5845199999999, 'YEAR_MONTH': 202206}
# {'SUM(ACTUAL_COST)': 43077.43722, 'YEAR_MONTH': 202206}
# {'SUM(ACTUAL_COST)': 329.55283, 'YEAR_MONTH': 202206}
# {'SUM(ACTUAL_COST)': 98.11208, 'YEAR_MONTH': 202206}
# {'SUM(ACTUAL_COST)': 602.2296, 'YEAR_MONTH': 202206}
# {'SUM(ACTUAL_COST)': 12565.14238, 'YEAR_MONTH': 202206}
# {'SUM(ACTUAL_COST)': 19197.452989999998, 'YEAR_MONTH': 202206}
# {'SUM(ACTUAL_COST)': 67533.46758, 'YEAR_MONTH': 202206}

# %%
# 6) C - Quais são as precrições mais comuns?

#Realizando a conexão com o banco
client = MongoClient('localhost', 27017)
database = client["banco"]
collection = database["tabela2"]

pipeline = [
    {
        u"$group": {
            u"_id": {
                u"BNF_PARAGRAPH": u"$BNF_PARAGRAPH"
            },
            u"COUNT(PRESCRIBED_PREP_CLASS)": {
                u"$sum": 1
            }
        }
    }, 
    {
        u"$project": {
            u"COUNT(PRESCRIBED_PREP_CLASS)": u"$COUNT(PRESCRIBED_PREP_CLASS)",
            u"BNF_PARAGRAPH": u"$_id.BNF_PARAGRAPH",
            u"_id": 0
        }
    }, 
    {
        u"$sort": SON([ (u"COUNT(PRESCRIBED_PREP_CLASS)", -1) ])
    }
]

cursor = collection.aggregate(
    pipeline, 
    allowDiskUse = True
)
try:
    for doc in cursor:
        print(doc)
finally:
    client.close()
# Out:
# {'COUNT(PRESCRIBED_PREP_CLASS)': 6004, 'BNF_PARAGRAPH': 'Beta-adrenoceptor blocking drugs'}
# {'COUNT(PRESCRIBED_PREP_CLASS)': 2963, 'BNF_PARAGRAPH': 'Proton pump inhibitors'}
# {'COUNT(PRESCRIBED_PREP_CLASS)': 2541, 'BNF_PARAGRAPH': 'Renin-angiotensin system drugs'}
# {'COUNT(PRESCRIBED_PREP_CLASS)': 2110, 'BNF_PARAGRAPH': 'H2-receptor antagonists'}
# {'COUNT(PRESCRIBED_PREP_CLASS)': 1981, 'BNF_PARAGRAPH': 'Antispasmodics and other drugs altering gut motility'}
# {'COUNT(PRESCRIBED_PREP_CLASS)': 1936, 'BNF_PARAGRAPH': 'Stimulant laxatives'}
# {'COUNT(PRESCRIBED_PREP_CLASS)': 1619, 'BNF_PARAGRAPH': 'Loop diuretics'}
# {'COUNT(PRESCRIBED_PREP_CLASS)': 1312, 'BNF_PARAGRAPH': 'Alpha-adrenoceptor blocking drugs'}
# {'COUNT(PRESCRIBED_PREP_CLASS)': 1138, 'BNF_PARAGRAPH': 'Drugs for arrhythmias'}
# {'COUNT(PRESCRIBED_PREP_CLASS)': 1056, 'BNF_PARAGRAPH': 'Aminosalicylates'}
# {'COUNT(PRESCRIBED_PREP_CLASS)': 970, 'BNF_PARAGRAPH': 'Potassium-sparing diuretics and aldosterone antagonists'}
# {'COUNT(PRESCRIBED_PREP_CLASS)': 956, 'BNF_PARAGRAPH': 'Osmotic laxatives'}
# {'COUNT(PRESCRIBED_PREP_CLASS)': 816, 'BNF_PARAGRAPH': 'Potassium sparing diuretics and compounds'}
# {'COUNT(PRESCRIBED_PREP_CLASS)': 764, 'BNF_PARAGRAPH': 'Centrally-acting antihypertensive drugs'}
# {'COUNT(PRESCRIBED_PREP_CLASS)': 686, 'BNF_PARAGRAPH': 'Thiazides and related diuretics'}
# {'COUNT(PRESCRIBED_PREP_CLASS)': 506, 'BNF_PARAGRAPH': 'Antacids and simeticone'}
# {'COUNT(PRESCRIBED_PREP_CLASS)': 418, 'BNF_PARAGRAPH': 'Corticosteroids'}
# {'COUNT(PRESCRIBED_PREP_CLASS)': 388, 'BNF_PARAGRAPH': 'Cardiac glycosides'}
# {'COUNT(PRESCRIBED_PREP_CLASS)': 380, 'BNF_PARAGRAPH': 'Drugs affecting biliary composition and flow'}
# {'COUNT(PRESCRIBED_PREP_CLASS)': 380, 'BNF_PARAGRAPH': 'Antimotility drugs'}
# {'COUNT(PRESCRIBED_PREP_CLASS)': 374, 'BNF_PARAGRAPH': 'Vasodilator antihypertensive drugs'}
# {'COUNT(PRESCRIBED_PREP_CLASS)': 287, 'BNF_PARAGRAPH': 'Faecal softeners'}
# {'COUNT(PRESCRIBED_PREP_CLASS)': 132, 'BNF_PARAGRAPH': 'Copound haemorrhoidal preparations with corticosteroid'}
# {'COUNT(PRESCRIBED_PREP_CLASS)': 85, 'BNF_PARAGRAPH': 'Compound alginates and proprietary indigestion preparations'}
# {'COUNT(PRESCRIBED_PREP_CLASS)': 69, 'BNF_PARAGRAPH': 'Rectal sclerosants'}
# {'COUNT(PRESCRIBED_PREP_CLASS)': 45, 'BNF_PARAGRAPH': 'Bulk-forming laxatives'}
# {'COUNT(PRESCRIBED_PREP_CLASS)': 42, 'BNF_PARAGRAPH': 'Other drugs used in constipation'}
# {'COUNT(PRESCRIBED_PREP_CLASS)': 42, 'BNF_PARAGRAPH': 'Chelates and complexes'}

# %%
# 6) D - Qual produto químico é mais prescrito por cada prescriber?

from bson.son import SON
from pymongo import MongoClient

#Realizando a conexão com o banco
client = MongoClient('localhost', 27017)
database = client["banco"]
collection = database["tabela1"]

# Aqui é listado o nome do prescriber/ Quantidade do Produto mais prescrito, Nome do Produto mais prescrito 
pipeline = [
    {
        u"$group": {
            u"_id": {
                u"CHEMICAL_SUBSTANCE_BNF_DESCR": u"$CHEMICAL_SUBSTANCE_BNF_DESCR",
                u"PRACTICE_NAME": u"$PRACTICE_NAME"
            },
            u"COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)": {
                u"$sum": 1
            }
        }
    }, 
    {
        u"$project": {
            u"PRACTICE_NAME": u"$_id.PRACTICE_NAME",
            u"COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)": u"$COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)",
            u"CHEMICAL_SUBSTANCE_BNF_DESCR": u"$_id.CHEMICAL_SUBSTANCE_BNF_DESCR",
            u"_id": 0
        }
    }, 
    {
        u"$group": {
            u"_id": None,
            u"distinct": {
                u"$addToSet": u"$$ROOT"
            }
        }
    }, 
    {
        u"$unwind": {
            u"path": u"$distinct",
            u"preserveNullAndEmptyArrays": False
        }
    }, 
    {
        u"$replaceRoot": {
            u"newRoot": u"$distinct"
        }
    }, 
    {
        u"$sort": SON([ (u"COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)", -1) ])
    }
]

cursor = collection.aggregate(
    pipeline, 
    allowDiskUse = True
)
try:
    for doc in cursor:
        print(doc)
finally:
    client.close()
# Out:
# {'PRACTICE_NAME': 'UNIDENTIFIED DOCTORS', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 31, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Wound Management & Other Dressings'}
# {'PRACTICE_NAME': 'UNIDENTIFIED DOCTORS', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 26, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Catheters'}
# {'PRACTICE_NAME': 'UNIDENTIFIED DOCTORS', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 17, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methadone hydrochloride'}
# {'PRACTICE_NAME': 'TURNING POINT - HEREFORDSHIRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 16, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methadone hydrochloride'}
# {'PRACTICE_NAME': 'ADDICTIONS SERVICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 15, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methadone hydrochloride'}
# {'PRACTICE_NAME': 'WE ARE WITH YOU NORTH LINCOLNSHIRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 14, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methadone hydrochloride'}
# {'PRACTICE_NAME': 'ANCORA MEDICAL PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 12, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Enteral nutrition'}
# {'PRACTICE_NAME': 'WE ARE WITH YOU NORTH EAST LINCOLNSHIRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 12, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methadone hydrochloride'}
# {'PRACTICE_NAME': 'BLACKPOOL LOCALITY CHS', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 11, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Wound Management & Other Dressings'}
# {'PRACTICE_NAME': 'HAXBY GROUP PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 11, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Enteral nutrition'}
# {'PRACTICE_NAME': 'UNIDENTIFIED DOCTORS', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 10, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methylphenidate hydrochloride'}
# {'PRACTICE_NAME': 'WOODA SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 10, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Wound Management & Other Dressings'}
# {'PRACTICE_NAME': 'UNIDENTIFIED DOCTORS', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 10, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Co-codamol (Codeine phosphate/paracetamol)'}
# {'PRACTICE_NAME': 'UNIDENTIFIED DOCTORS', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 10, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Eye Products'}
# {'PRACTICE_NAME': 'CGL BIRMINGHAM SOUTH', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 10, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methadone hydrochloride'}
# {'PRACTICE_NAME': 'UNIDENTIFIED DOCTORS', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 9, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Enteral nutrition'}
# {'PRACTICE_NAME': 'HAXBY GROUP PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 9, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Levothyroxine sodium'}
# {'PRACTICE_NAME': 'COMMUNITY SUBSTANCE MISUSE TEAM', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 9, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methadone hydrochloride'}
# {'PRACTICE_NAME': 'CGL EAST CHESHIRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 9, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methadone hydrochloride'}
# {'PRACTICE_NAME': 'CLEE MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 9, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Wound Management & Other Dressings'}
# {'PRACTICE_NAME': 'UNIDENTIFIED DOCTORS', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 9, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Prednisolone'}
# {'PRACTICE_NAME': 'TURNING POINT LEICESTERSHRE COUNTY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 9, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methadone hydrochloride'}
# {'PRACTICE_NAME': 'WE ARE WITH YOU NORTH LINCOLNSHIRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 9, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Buprenorphine hydrochloride'}
# {'PRACTICE_NAME': 'ROCHDALE AND OLDHAM ACTIVE RECOVERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 9, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methadone hydrochloride'}
# {'PRACTICE_NAME': 'SPRING TERRACE HEALTH CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 8, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Colecalciferol'}
# {'PRACTICE_NAME': 'PELHAM MEDICAL GROUP', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 8, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methadone hydrochloride'}
# {'PRACTICE_NAME': 'THE CENTRAL SURGERY BARTON', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 8, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Colecalciferol'}
# {'PRACTICE_NAME': 'HAXBY GROUP PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 8, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Catheters'}
# {'PRACTICE_NAME': 'CGL EAST CHESHIRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 8, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Buprenorphine hydrochloride'}
# {'PRACTICE_NAME': 'CGL KIRKLEES', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 8, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methadone hydrochloride'}
# {'PRACTICE_NAME': 'UNIDENTIFIED DOCTORS', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 8, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Other Appliances'}
# {'PRACTICE_NAME': 'FORWARD LEEDS', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 8, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methadone hydrochloride'}
# {'PRACTICE_NAME': 'ADELAIDE STREET SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 7, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Enteral nutrition'}
# {'PRACTICE_NAME': 'THE KIRTON LINDSEY AND SCOTTER SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 7, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Colecalciferol'}
# {'PRACTICE_NAME': 'ANCORA MEDICAL PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 7, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Gabapentin'}
# {'PRACTICE_NAME': 'WOODA SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 7, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Enteral nutrition'}
# {'PRACTICE_NAME': 'WE ARE WITH YOU CORNWALL CENTRAL', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 7, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methadone hydrochloride'}
# {'PRACTICE_NAME': 'ADDICTIONS SERVICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 7, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Buprenorphine hydrochloride'}
# {'PRACTICE_NAME': 'UNIDENTIFIED DOCTORS', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 7, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Lymphoedema Garments'}
# {'PRACTICE_NAME': 'CGL CAMBRIDGESHIRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 7, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methadone hydrochloride'}
# {'PRACTICE_NAME': 'HAXBY GROUP PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 7, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Colecalciferol'}
# {'PRACTICE_NAME': 'NEWTON DRIVE HEALTH CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 7, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Emollients'}
# {'PRACTICE_NAME': 'CGL WIRRAL', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 7, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methadone hydrochloride'}
# {'PRACTICE_NAME': 'EAST KENT DRUG AND ALCOHOL SERVICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 7, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methadone hydrochloride'}
# {'PRACTICE_NAME': 'HELMSLEY SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 7, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Colecalciferol'}
# {'PRACTICE_NAME': 'SUNNYSIDE MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 7, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Colecalciferol'}
# {'PRACTICE_NAME': 'BRADFORD NEW DIRECTIONS', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 7, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methadone hydrochloride'}
# {'PRACTICE_NAME': 'THE CENTRAL SURGERY BARTON', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 7, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Other Appliances'}
# {'PRACTICE_NAME': 'HELMSLEY SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 6, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Wound Management & Other Dressings'}
# {'PRACTICE_NAME': 'DINNINGTON GROUP PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 6, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Combined ethinylestradiol 30mcg'}
# {'PRACTICE_NAME': 'HAXBY GROUP PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 6, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Wound Management & Other Dressings'}
# {'PRACTICE_NAME': 'UNIDENTIFIED DOCTORS', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 6, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Emollients'}
# {'PRACTICE_NAME': 'UNIDENTIFIED DOCTORS', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 6, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Night Drainage Bags'}
# {'PRACTICE_NAME': 'UNIDENTIFIED DOCTORS', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 6, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Incontinence Sheaths'}
# {'PRACTICE_NAME': 'BLACKPOOL SUBSTANCE MISUSE SERVICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 6, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methadone hydrochloride'}
# {'PRACTICE_NAME': 'CPT WORTHING', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 6, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methadone hydrochloride'}
# {'PRACTICE_NAME': 'TRENT VIEW MEDICAL PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 6, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Other Appliances'}
# {'PRACTICE_NAME': 'GLOUCESTERSHIRE DRUG & ALCOHOL RECOVERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 6, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methadone hydrochloride'}
# {'PRACTICE_NAME': 'ANCORA MEDICAL PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 6, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Other Appliances'}
# {'PRACTICE_NAME': 'HAXBY GROUP PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 6, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Emollients'}
# {'PRACTICE_NAME': 'DARTMOUTH MEDICAL PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 6, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Wound Management & Other Dressings'}
# {'PRACTICE_NAME': 'MIDAS', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 6, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methadone hydrochloride'}
# {'PRACTICE_NAME': 'WINGATE MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 6, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Levothyroxine sodium'}
# {'PRACTICE_NAME': 'HAXBY GROUP PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 6, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Co-codamol (Codeine phosphate/paracetamol)'}
# {'PRACTICE_NAME': 'START', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 6, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methadone hydrochloride'}
# {'PRACTICE_NAME': 'SPRING HALL GROUP PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 6, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Quetiapine'}
# {'PRACTICE_NAME': 'KINGSTEIGNTON MEDICAL PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 6, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Wound Management & Other Dressings'}
# {'PRACTICE_NAME': 'BEACON MEDICAL', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 6, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Wound Management & Other Dressings'}
# {'PRACTICE_NAME': 'UNIDENTIFIED DOCTORS', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 6, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Dulaglutide'}
# {'PRACTICE_NAME': 'CLAYHILL MEDICAL PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 6, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Other Appliances'}
# {'PRACTICE_NAME': 'UNIDENTIFIED DOCTORS', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 6, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Buprenorphine hydrochloride'}
# {'PRACTICE_NAME': 'STAFFORDSHIRE TREATMENT&RECOVERY SERVICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 6, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methadone hydrochloride'}
# {'PRACTICE_NAME': 'SPRING HALL GROUP PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 6, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Enteral nutrition'}
# {'PRACTICE_NAME': 'TRENT VIEW MEDICAL PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 6, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Colecalciferol'}
# {'PRACTICE_NAME': 'HAXBY GROUP PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 6, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Estradiol'}
# {'PRACTICE_NAME': 'CRESCENT PROVIDENCE SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 6, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Colecalciferol'}
# {'PRACTICE_NAME': 'ANCORA MEDICAL PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 6, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Colecalciferol'}
# {'PRACTICE_NAME': 'THE JUNCTION SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 6, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Colecalciferol'}
# {'PRACTICE_NAME': 'THE JUNCTION SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 6, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Propranolol hydrochloride'}
# {'PRACTICE_NAME': 'THE CENTRAL SURGERY BARTON', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 6, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Wound Management & Other Dressings'}
# {'PRACTICE_NAME': 'CARE PLUS GROUP', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 6, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Wound Management & Other Dressings'}
# {'PRACTICE_NAME': 'INSPIRING RECOVERY - WAKEFIELD', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 6, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methadone hydrochloride'}
# {'PRACTICE_NAME': 'WINGATE MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Enteral nutrition'}
# {'PRACTICE_NAME': 'UNIDENTIFIED DOCTORS', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Aspirin'}
# {'PRACTICE_NAME': 'CAMBRIDGE AVENUE MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Pregabalin'}
# {'PRACTICE_NAME': 'KEPIER MEDICAL PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Other Appliances'}
# {'PRACTICE_NAME': 'DINNINGTON GROUP PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Co-codamol (Codeine phosphate/paracetamol)'}
# {'PRACTICE_NAME': 'DEERNESS PARK MEDICAL GROUP', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Codeine phosphate'}
# {'PRACTICE_NAME': 'WE ARE WITH YOU NORTH EAST LINCOLNSHIRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Buprenorphine hydrochloride'}
# {'PRACTICE_NAME': 'CLEE MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Colecalciferol'}
# {'PRACTICE_NAME': 'DINNINGTON GROUP PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Gabapentin'}
# {'PRACTICE_NAME': 'DINNINGTON GROUP PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Alginic acid compound preparations'}
# {'PRACTICE_NAME': 'THE KIRTON LINDSEY AND SCOTTER SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Other Appliances'}
# {'PRACTICE_NAME': 'MARKET SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Emollients'}
# {'PRACTICE_NAME': 'WARWICKSHIRE DRUG & ALCOHOL RECOVERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methadone hydrochloride'}
# {'PRACTICE_NAME': 'BEACON MEDICAL', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Isosorbide mononitrate'}
# {'PRACTICE_NAME': 'ANCORA MEDICAL PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Metformin hydrochloride'}
# {'PRACTICE_NAME': 'STOCKTON HEATH MED.CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Other Appliances'}
# {'PRACTICE_NAME': 'ANCORA MEDICAL PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Quetiapine'}
# {'PRACTICE_NAME': 'PRIMARY CARE DRUGS SERVICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methadone hydrochloride'}
# {'PRACTICE_NAME': 'RECOVERY STEPS CUMBRIA', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methadone hydrochloride'}
# {'PRACTICE_NAME': 'VALENS MEDICAL PARTNERSHIP', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Enteral nutrition'}
# {'PRACTICE_NAME': 'UNIDENTIFIED DOCTORS', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Pregabalin'}
# {'PRACTICE_NAME': 'STAR - EAST SUSSEX DRUG & ALCOHOL SERV', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methadone hydrochloride'}
# {'PRACTICE_NAME': 'NMS CGL NOTTINGHAMSHIRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methadone hydrochloride'}
# {'PRACTICE_NAME': 'BLUNDELLSANDS SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Colecalciferol'}
# {'PRACTICE_NAME': 'BEACON MEDICAL', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Other Appliances'}
# {'PRACTICE_NAME': 'DINNINGTON GROUP PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Prednisolone'}
# {'PRACTICE_NAME': 'HAXBY GROUP PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Morphine sulfate'}
# {'PRACTICE_NAME': 'CGL TOWER HAMLETS', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methadone hydrochloride'}
# {'PRACTICE_NAME': 'WINGATE MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Venlafaxine'}
# {'PRACTICE_NAME': 'SUNNYSIDE MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Amlodipine'}
# {'PRACTICE_NAME': 'CLEE MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Quetiapine'}
# {'PRACTICE_NAME': 'BLUNDELLSANDS SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Other Appliances'}
# {'PRACTICE_NAME': 'UNIDENTIFIED DOCTORS', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Levothyroxine sodium'}
# {'PRACTICE_NAME': 'ANCORA MEDICAL PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Atorvastatin'}
# {'PRACTICE_NAME': 'KIRKBYMOORSIDE SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Eye Products'}
# {'PRACTICE_NAME': 'CAMBRIDGE AVENUE MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Oxycodone hydrochloride'}
# {'PRACTICE_NAME': 'THE BRIDGES MEDICAL CTR.', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Other emollient preparations'}
# {'PRACTICE_NAME': 'UNIDENTIFIED DOCTORS', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Lamotrigine'}
# {'PRACTICE_NAME': 'RIVERSIDE SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Diltiazem hydrochloride'}
# {'PRACTICE_NAME': 'SOUTHEND TREATMENT AND RECOVERY SERVICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methadone hydrochloride'}
# {'PRACTICE_NAME': 'THE CENTRAL SURGERY BARTON', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Carbamazepine'}
# {'PRACTICE_NAME': 'TURNING POINT - HEREFORDSHIRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Buprenorphine hydrochloride'}
# {'PRACTICE_NAME': 'LIVERPOOL RD MEDICAL PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Colecalciferol'}
# {'PRACTICE_NAME': 'BEACON MEDICAL GROUP', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Venlafaxine'}
# {'PRACTICE_NAME': 'LIVERPOOL RD MEDICAL PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Other Appliances'}
# {'PRACTICE_NAME': 'TREETON MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Colecalciferol'}
# {'PRACTICE_NAME': 'STOCKTON HEATH MED.CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Co-codamol (Codeine phosphate/paracetamol)'}
# {'PRACTICE_NAME': 'RIVERSIDE SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Morphine sulfate'}
# {'PRACTICE_NAME': 'PENNINE CARE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methadone hydrochloride'}
# {'PRACTICE_NAME': 'SUNNYSIDE MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Gabapentin'}
# {'PRACTICE_NAME': 'THE CENTRAL SURGERY BARTON', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Budesonide'}
# {'PRACTICE_NAME': 'UNIDENTIFIED DOCTORS', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Estradiol'}
# {'PRACTICE_NAME': 'HAXBY GROUP PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Other Appliances'}
# {'PRACTICE_NAME': 'UNIDENTIFIED DOCTORS', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Olanzapine'}
# {'PRACTICE_NAME': 'RIVERSIDE SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Colecalciferol'}
# {'PRACTICE_NAME': 'WOODA SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Colecalciferol'}
# {'PRACTICE_NAME': 'CGL-NEWHAM RISE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methadone hydrochloride'}
# {'PRACTICE_NAME': 'THE AVENUE SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Colecalciferol'}
# {'PRACTICE_NAME': 'BLUNDELLSANDS SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Glucose blood testing reagents'}
# {'PRACTICE_NAME': 'FORWARD LEEDS', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Buprenorphine hydrochloride'}
# {'PRACTICE_NAME': 'SHERBURN GROUP PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Prednisolone'}
# {'PRACTICE_NAME': 'SEATON PARK MEDICAL GROUP', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Enteral nutrition'}
# {'PRACTICE_NAME': 'HONITON SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Wound Management & Other Dressings'}
# {'PRACTICE_NAME': 'DARTMOUTH MEDICAL PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Prednisolone'}
# {'PRACTICE_NAME': 'RIVERSIDE SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Enteral nutrition'}
# {'PRACTICE_NAME': 'RIVERSIDE SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Quetiapine'}
# {'PRACTICE_NAME': 'WESTBOURNE MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Enteral nutrition'}
# {'PRACTICE_NAME': 'SWARLAND AVENUE SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Estradiol'}
# {'PRACTICE_NAME': 'PELHAM MEDICAL GROUP', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Wound Management & Other Dressings'}
# {'PRACTICE_NAME': 'THE LYNTON PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Wound Management & Other Dressings'}
# {'PRACTICE_NAME': 'WINTERTON MEDICAL PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 5, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Colecalciferol'}
# {'PRACTICE_NAME': 'TREETON MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Metronidazole'}
# {'PRACTICE_NAME': 'NORTH LINCS DERMATOLOGY SERVICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methotrexate'}
# {'PRACTICE_NAME': 'CHAPELFORD PRIMARY CARE CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Beclometasone dipropionate'}
# {'PRACTICE_NAME': 'SHERBURN GROUP PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Colecalciferol'}
# {'PRACTICE_NAME': 'CLEE MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Enteral nutrition'}
# {'PRACTICE_NAME': 'HAXBY GROUP PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Skin Fillers And Protectives'}
# {'PRACTICE_NAME': 'CGL NORTH & CENTRAL LANCASHIRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methadone hydrochloride'}
# {'PRACTICE_NAME': 'TRENT VIEW MEDICAL PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Fentanyl'}
# {'PRACTICE_NAME': 'SOUTHAMPTON DRUG & ALCOHOL SERVICES', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methadone hydrochloride'}
# {'PRACTICE_NAME': 'THE CENTRAL SURGERY BARTON', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Isosorbide mononitrate'}
# {'PRACTICE_NAME': 'UNIDENTIFIED DOCTORS', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Catheter Maintenance Products'}
# {'PRACTICE_NAME': 'BEACON MEDICAL GROUP', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Colecalciferol'}
# {'PRACTICE_NAME': 'WINTERTON MEDICAL PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Prednisolone'}
# {'PRACTICE_NAME': 'SPRING TERRACE HEALTH CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Hydrocortisone'}
# {'PRACTICE_NAME': 'AXMINSTER MEDICAL PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Morphine sulfate'}
# {'PRACTICE_NAME': 'KNOWLE HOUSE SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Pregabalin'}
# {'PRACTICE_NAME': 'UNIDENTIFIED DOCTORS', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Amoxicillin'}
# {'PRACTICE_NAME': 'LIVERPOOL RD MEDICAL PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Tramadol hydrochloride'}
# {'PRACTICE_NAME': 'CAMBRIDGE AVENUE MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Emollients'}
# {'PRACTICE_NAME': 'UNIDENTIFIED DOCTORS', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Melatonin'}
# {'PRACTICE_NAME': 'RIVERSIDE SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Naproxen'}
# {'PRACTICE_NAME': 'THE OSWALD ROAD MEDICAL SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Colecalciferol'}
# {'PRACTICE_NAME': 'UNIDENTIFIED DOCTORS', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Prochlorperazine maleate'}
# {'PRACTICE_NAME': 'CLEE MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Hydrocortisone'}
# {'PRACTICE_NAME': 'DINNINGTON GROUP PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Paracetamol'}
# {'PRACTICE_NAME': 'PELHAM MEDICAL GROUP', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Colecalciferol'}
# {'PRACTICE_NAME': 'ST PAULS MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Gabapentin'}
# {'PRACTICE_NAME': 'BEACON MEDICAL', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Enteral nutrition'}
# {'PRACTICE_NAME': 'DARTMOUTH MEDICAL PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Co-codamol (Codeine phosphate/paracetamol)'}
# {'PRACTICE_NAME': 'ANCORA MEDICAL PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Venlafaxine'}
# {'PRACTICE_NAME': 'BLUNDELLSANDS SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Estradiol'}
# {'PRACTICE_NAME': 'WINGATE MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Co-codamol (Codeine phosphate/paracetamol)'}
# {'PRACTICE_NAME': 'MAYFLOWER MEDICAL GROUP', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Enteral nutrition'}
# {'PRACTICE_NAME': 'HAMMERSMITH AND FULHAM DAWS', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methadone hydrochloride'}
# {'PRACTICE_NAME': 'ROBOROUGH SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Doxazosin mesilate'}
# {'PRACTICE_NAME': "ST. LAURENCE'S MEDICAL CENTRE", 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Co-dydramol (Dihydrocodeine/paracetamol)'}
# {'PRACTICE_NAME': 'DEVONPORT HEALTH CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Co-codamol (Codeine phosphate/paracetamol)'}
# {'PRACTICE_NAME': 'SHELLEY MANOR HOLDENHURST MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Venlafaxine'}
# {'PRACTICE_NAME': 'MAYFIELD MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Enteral nutrition'}
# {'PRACTICE_NAME': 'GALLERIES MEDICAL PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Ramipril'}
# {'PRACTICE_NAME': 'CGL RESOLUTIONS SERVICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methadone hydrochloride'}
# {'PRACTICE_NAME': 'SOUTH BRENT HEALTH CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Other Appliances'}
# {'PRACTICE_NAME': 'BLUNDELLSANDS SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Paracetamol'}
# {'PRACTICE_NAME': 'OXFORDSHIRE ROADS TO RECOVERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methadone hydrochloride'}
# {'PRACTICE_NAME': 'KINGSWAY SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Enteral nutrition'}
# {'PRACTICE_NAME': 'WEAVER VALE PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Co-codamol (Codeine phosphate/paracetamol)'}
# {'PRACTICE_NAME': 'HAXBY GROUP PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Carbamazepine'}
# {'PRACTICE_NAME': 'VALENS MEDICAL PARTNERSHIP', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Quetiapine'}
# {'PRACTICE_NAME': 'DARWEN HEALTHLINK', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Co-codamol (Codeine phosphate/paracetamol)'}
# {'PRACTICE_NAME': 'HETTON GROUP PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Carbamazepine'}
# {'PRACTICE_NAME': 'THE KIRTON LINDSEY AND SCOTTER SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Co-careldopa (Carbidopa/levodopa)'}
# {'PRACTICE_NAME': 'CGL SERVICES', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methadone hydrochloride'}
# {'PRACTICE_NAME': 'CGL NORFOLK', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Buprenorphine hydrochloride'}
# {'PRACTICE_NAME': 'SPRING HALL GROUP PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Colecalciferol'}
# {'PRACTICE_NAME': 'CASTLE PLACE PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Other Appliances'}
# {'PRACTICE_NAME': 'CAMBRIDGE AVENUE MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Venlafaxine'}
# {'PRACTICE_NAME': 'TURNING POINT - H&CRS (HACKNEY)', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methadone hydrochloride'}
# {'PRACTICE_NAME': 'WOODA SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Estradiol'}
# {'PRACTICE_NAME': 'COLLEGE SURGERY PARTNERSHIP', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Wound Management & Other Dressings'}
# {'PRACTICE_NAME': 'UNIDENTIFIED DOCTORS', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Clarithromycin'}
# {'PRACTICE_NAME': 'THE JUNCTION SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Co-codamol (Codeine phosphate/paracetamol)'}
# {'PRACTICE_NAME': 'WE ARE WITH YOU SHROPSHIRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methadone hydrochloride'}
# {'PRACTICE_NAME': 'UNIDENTIFIED DOCTORS', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Colecalciferol'}
# {'PRACTICE_NAME': 'THE LYNTON PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Metformin hydrochloride'}
# {'PRACTICE_NAME': 'UNIDENTIFIED DOCTORS', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Anal Irrigation System'}
# {'PRACTICE_NAME': 'HAXBY GROUP PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Bumetanide'}
# {'PRACTICE_NAME': 'ST GEORGES SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Colecalciferol'}
# {'PRACTICE_NAME': 'THE AVENUE SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Levothyroxine sodium'}
# {'PRACTICE_NAME': 'UNIDENTIFIED DOCTORS', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Stockinette'}
# {'PRACTICE_NAME': 'DINNINGTON GROUP PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Beclometasone dipropionate'}
# {'PRACTICE_NAME': 'UNIDENTIFIED DOCTORS', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Lansoprazole'}
# {'PRACTICE_NAME': 'UNIDENTIFIED DOCTORS', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Naproxen'}
# {'PRACTICE_NAME': 'RIVERSIDE SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Co-codamol (Codeine phosphate/paracetamol)'}
# {'PRACTICE_NAME': 'MARKET SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Estradiol'}
# {'PRACTICE_NAME': 'ASHBURTON SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Colecalciferol'}
# {'PRACTICE_NAME': 'UNIDENTIFIED DOCTORS', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Tracheostomy & Laryngectomy Appliances'}
# {'PRACTICE_NAME': 'WEAVER VALE PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Carbamazepine'}
# {'PRACTICE_NAME': 'SUNNYSIDE MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Wound Management & Other Dressings'}
# {'PRACTICE_NAME': 'UNIDENTIFIED DOCTORS', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Other individually formulated bought in preparations'}
# {'PRACTICE_NAME': 'SOUTH LAWN MEDICAL PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Perindopril erbumine'}
# {'PRACTICE_NAME': 'PSYCHIATRY-UK', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methylphenidate hydrochloride'}
# {'PRACTICE_NAME': 'RIVERSIDE SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Eye Products'}
# {'PRACTICE_NAME': 'COLLEGE SURGERY PARTNERSHIP', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Diazepam'}
# {'PRACTICE_NAME': 'CLEE MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Diazepam'}
# {'PRACTICE_NAME': 'STONYHILL MEDICAL PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Colecalciferol'}
# {'PRACTICE_NAME': 'CAMBRIDGE AVENUE MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Gabapentin'}
# {'PRACTICE_NAME': 'WINGATE MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Dihydrocodeine tartrate'}
# {'PRACTICE_NAME': 'PEEL GPS', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Other Appliances'}
# {'PRACTICE_NAME': 'THE LYNTON PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Enteral nutrition'}
# {'PRACTICE_NAME': 'SUNNYSIDE MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Levothyroxine sodium'}
# {'PRACTICE_NAME': 'PINHOE SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Colecalciferol'}
# {'PRACTICE_NAME': 'UNIDENTIFIED DOCTORS', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Salbutamol'}
# {'PRACTICE_NAME': 'UNIDENTIFIED DOCTORS', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Chlorphenamine maleate'}
# {'PRACTICE_NAME': 'DINNINGTON GROUP PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Colecalciferol'}
# {'PRACTICE_NAME': 'IMPERIAL SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Colecalciferol'}
# {'PRACTICE_NAME': 'KINGSWAY SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Co-codamol (Codeine phosphate/paracetamol)'}
# {'PRACTICE_NAME': 'THE KIRTON LINDSEY AND SCOTTER SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Macrogol 3350'}
# {'PRACTICE_NAME': 'BEACON MEDICAL', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Pregabalin'}
# {'PRACTICE_NAME': 'THE CENTRAL SURGERY BARTON', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Pregabalin'}
# {'PRACTICE_NAME': 'UNIDENTIFIED DOCTORS', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Lymecycline'}
# {'PRACTICE_NAME': 'WOODA SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Skin Fillers And Protectives'}
# {'PRACTICE_NAME': 'SUNNYSIDE MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Morphine sulfate'}
# {'PRACTICE_NAME': 'BEACON MEDICAL', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Ramipril'}
# {'PRACTICE_NAME': 'UNIDENTIFIED DOCTORS', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Fexofenadine hydrochloride'}
# {'PRACTICE_NAME': 'ANCORA MEDICAL PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Levothyroxine sodium'}
# {'PRACTICE_NAME': 'DINNINGTON GROUP PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Pregabalin'}
# {'PRACTICE_NAME': 'WEAVER VALE PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Colecalciferol'}
# {'PRACTICE_NAME': 'WESTBOURNE MEDICAL GROUP', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Colecalciferol'}
# {'PRACTICE_NAME': 'WATERLOO MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Co-codamol (Codeine phosphate/paracetamol)'}
# {'PRACTICE_NAME': 'DARTMOUTH MEDICAL PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Metformin hydrochloride'}
# {'PRACTICE_NAME': 'WOODA SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Hydrocortisone'}
# {'PRACTICE_NAME': 'CHANNEL VIEW MEDICAL GROUP', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Colecalciferol'}
# {'PRACTICE_NAME': 'SUNNYSIDE MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Other Appliances'}
# {'PRACTICE_NAME': 'THE KILLINGHOLME SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Bisoprolol fumarate'}
# {'PRACTICE_NAME': 'QUAYSIDE MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Venlafaxine'}
# {'PRACTICE_NAME': 'ANCORA MEDICAL PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Tramadol hydrochloride'}
# {'PRACTICE_NAME': 'CLEE MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Tiotropium bromide'}
# {'PRACTICE_NAME': 'SWARLAND AVENUE SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Other Appliances'}
# {'PRACTICE_NAME': 'SHERBURN GROUP PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Lansoprazole'}
# {'PRACTICE_NAME': 'HAXBY GROUP PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Combined ethinylestradiol 30mcg'}
# {'PRACTICE_NAME': 'STONYHILL MEDICAL PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Levetiracetam'}
# {'PRACTICE_NAME': "ST. LAURENCE'S MEDICAL CENTRE", 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Glucose blood testing reagents'}
# {'PRACTICE_NAME': 'ANCORA MEDICAL PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Baclofen'}
# {'PRACTICE_NAME': 'WEST TIMPERLEY MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Propranolol hydrochloride'}
# {'PRACTICE_NAME': 'KIRKBYMOORSIDE SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Enteral nutrition'}
# {'PRACTICE_NAME': 'TRENT VIEW MEDICAL PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Carbocisteine'}
# {'PRACTICE_NAME': 'ADELAIDE STREET SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Other Appliances'}
# {'PRACTICE_NAME': 'HONITON SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Colecalciferol'}
# {'PRACTICE_NAME': 'RIBBLESDALE MEDICAL PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Co-codamol (Codeine phosphate/paracetamol)'}
# {'PRACTICE_NAME': 'CLEE MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Pregabalin'}
# {'PRACTICE_NAME': 'VILLETTE SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Colecalciferol'}
# {'PRACTICE_NAME': 'SPRING HALL GROUP PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Amitriptyline hydrochloride'}
# {'PRACTICE_NAME': 'TALBOT MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Sodium valproate'}
# {'PRACTICE_NAME': 'PEMBROKE MEDICAL GROUP', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Prednisolone'}
# {'PRACTICE_NAME': 'TREETON MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Ramipril'}
# {'PRACTICE_NAME': 'STOCKTON HEATH MED.CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Colecalciferol'}
# {'PRACTICE_NAME': 'ROYAL MANOR HEALTH CARE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Quetiapine'}
# {'PRACTICE_NAME': 'UNIDENTIFIED DOCTORS', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Quetiapine'}
# {'PRACTICE_NAME': 'THE KIRTON LINDSEY AND SCOTTER SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Enteral nutrition'}
# {'PRACTICE_NAME': 'UNIDENTIFIED DOCTORS', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methotrexate'}
# {'PRACTICE_NAME': 'THE CENTRAL SURGERY BARTON', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Bisoprolol fumarate'}
# {'PRACTICE_NAME': 'DR MALHOTRA & PARTNERS', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Enteral nutrition'}
# {'PRACTICE_NAME': 'KIRKBYMOORSIDE SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Other Appliances'}
# {'PRACTICE_NAME': 'THE OSWALD ROAD MEDICAL SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Ramipril'}
# {'PRACTICE_NAME': 'WINTERTON MEDICAL PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Paracetamol'}
# {'PRACTICE_NAME': 'WOODBANK SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Hydrocortisone'}
# {'PRACTICE_NAME': 'COMPASS HOUSE MEDICAL CENTRES', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Estradiol'}
# {'PRACTICE_NAME': 'THE AVENUE SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Other Appliances'}
# {'PRACTICE_NAME': 'CLEE MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Macrogol 3350'}
# {'PRACTICE_NAME': 'HAXBY GROUP PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methotrexate'}
# {'PRACTICE_NAME': 'ANCORA MEDICAL PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Emollients'}
# {'PRACTICE_NAME': 'SPRING HALL GROUP PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Macrogol 3350'}
# {'PRACTICE_NAME': 'UNIDENTIFIED DOCTORS', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Dexamfetamine sulfate'}
# {'PRACTICE_NAME': 'THORPE HESLEY SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Emollients'}
# {'PRACTICE_NAME': 'PEEL GPS', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Gabapentin'}
# {'PRACTICE_NAME': 'UNIDENTIFIED DOCTORS', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Folic acid'}
# {'PRACTICE_NAME': 'KILDONAN HOUSE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Tramadol hydrochloride'}
# {'PRACTICE_NAME': 'WEST TIMPERLEY MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Colecalciferol'}
# {'PRACTICE_NAME': 'SWARLAND AVENUE SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Enteral nutrition'}
# {'PRACTICE_NAME': 'SOUTHBOURNE PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Colecalciferol'}
# {'PRACTICE_NAME': 'UNIDENTIFIED DOCTORS', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Hydrocortisone'}
# {'PRACTICE_NAME': 'ST THOMAS MEDICAL GROUP', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Wound Management & Other Dressings'}
# {'PRACTICE_NAME': 'CORNER PLACE SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Eye Products'}
# {'PRACTICE_NAME': 'INSPIRE CGL', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methadone hydrochloride'}
# {'PRACTICE_NAME': 'UNIDENTIFIED DOCTORS', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Metformin hydrochloride'}
# {'PRACTICE_NAME': 'KIRKBYMOORSIDE SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Co-beneldopa (Benserazide/levodopa)'}
# {'PRACTICE_NAME': 'DINNINGTON GROUP PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Metformin hydrochloride'}
# {'PRACTICE_NAME': 'HELMSLEY SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Ibuprofen'}
# {'PRACTICE_NAME': 'BLUNDELLSANDS SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Perindopril erbumine'}
# {'PRACTICE_NAME': 'HAXBY GROUP PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Gabapentin'}
# {'PRACTICE_NAME': 'WINTERTON MEDICAL PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Gabapentin'}
# {'PRACTICE_NAME': 'KINGSWAY SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Colecalciferol'}
# {'PRACTICE_NAME': 'CRANSTOUN WORCESTERSHIRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methadone hydrochloride'}
# {'PRACTICE_NAME': 'RIBBLESDALE MEDICAL PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Prednisolone'}
# {'PRACTICE_NAME': 'ST NEOTS SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Colecalciferol'}
# {'PRACTICE_NAME': 'CLAYHILL MEDICAL PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Venlafaxine'}
# {'PRACTICE_NAME': 'UNIDENTIFIED DOCTORS', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Leg Bags'}
# {'PRACTICE_NAME': 'WOODLEA HOUSE SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Wound Management & Other Dressings'}
# {'PRACTICE_NAME': 'DINNINGTON GROUP PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Ibuprofen'}
# {'PRACTICE_NAME': 'WEST TOWN SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Gabapentin'}
# {'PRACTICE_NAME': 'STONYHILL MEDICAL PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Ferrous sulfate'}
# {'PRACTICE_NAME': 'SWAN LANE MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Co-codamol (Codeine phosphate/paracetamol)'}
# {'PRACTICE_NAME': 'DINNINGTON GROUP PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Oxycodone hydrochloride'}
# {'PRACTICE_NAME': 'BLUNDELLSANDS SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Enteral nutrition'}
# {'PRACTICE_NAME': 'SPRING HALL GROUP PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Fluticasone propionate (Inhalation)'}
# {'PRACTICE_NAME': 'STONYHILL MEDICAL PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 4, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Candesartan cilexetil'}
# ...
# {'PRACTICE_NAME': 'BEACON MEDICAL GROUP', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Estradiol valerate'}
# {'PRACTICE_NAME': 'LITTLE LEVER HEALTH CENTRE 2', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Miconazole'}
# {'PRACTICE_NAME': 'WHIPTON SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Pregabalin'}
# {'PRACTICE_NAME': 'KNIGHTS SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Isophane insulin'}
# {'PRACTICE_NAME': 'AL FAL MEDICAL GROUP', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Amlodipine'}
# {'PRACTICE_NAME': 'CAEN MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Candesartan cilexetil'}
# {'PRACTICE_NAME': 'ALBANY SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Beclometasone dipropionate'}
# {'PRACTICE_NAME': 'DINNINGTON GROUP PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'INR blood testing reagents'}
# {'PRACTICE_NAME': 'OLD FARM SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Arm Sling/Bandages'}
# {'PRACTICE_NAME': 'HAPPY HOUSE SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Pancreatin'}
# {'PRACTICE_NAME': 'STONYHILL MEDICAL PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methotrexate'}
# {'PRACTICE_NAME': 'ST HELENS ROAD PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Other Appliances'}
# {'PRACTICE_NAME': 'SID VALLEY PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Chlorphenamine maleate'}
# {'PRACTICE_NAME': 'NORTON BROOK MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Co-amoxiclav (Amoxicillin/clavulanic acid)'}
# {'PRACTICE_NAME': 'QUEENS AVENUE SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Flucloxacillin sodium'}
# {'PRACTICE_NAME': 'BRIDGE STREET SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Budesonide'}
# {'PRACTICE_NAME': 'WOODA SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Miconazole'}
# {'PRACTICE_NAME': 'ISLE OF WIGHT NHS TRUST NMP', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Nystatin'}
# {'PRACTICE_NAME': 'LISSON GROVE MEDICAL CTR.', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Sulfasalazine'}
# {'PRACTICE_NAME': 'ROBOROUGH SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Two Piece Ostomy Systems'}
# {'PRACTICE_NAME': 'BRANNAM MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Fosfomycin trometamol'}
# {'PRACTICE_NAME': 'CORE CARE FAMILY PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Wound Management & Other Dressings'}
# {'PRACTICE_NAME': 'ROBOROUGH SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Topiramate'}
# {'PRACTICE_NAME': 'AMICUS HEALTH', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Brinzolamide'}
# {'PRACTICE_NAME': 'LITTLE LEVER HEALTH CENTRE 1', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Rabeprazole sodium'}
# {'PRACTICE_NAME': 'WEST TOWN SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Other base/diluent/suspending agent/stabiliser preparations'}
# {'PRACTICE_NAME': 'PATHFIELDS MEDICAL GROUP', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Phenoxymethylpenicillin (Penicillin V)'}
# {'PRACTICE_NAME': 'THE LYNTON PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Irrigation Solutions'}
# {'PRACTICE_NAME': 'MARKET SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Mizolastine'}
# {'PRACTICE_NAME': 'CHAPELFORD PRIMARY CARE CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Colchicine'}
# {'PRACTICE_NAME': 'THE DORCHESTER RD SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Fluticasone propionate (Inhalation)'}
# {'PRACTICE_NAME': 'CATHERINE HOUSE SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Terbinafine hydrochloride'}
# {'PRACTICE_NAME': 'OAKENHURST MEDICAL PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Felodipine'}
# {'PRACTICE_NAME': 'CHAPELFORD PRIMARY CARE CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Zolmitriptan'}
# {'PRACTICE_NAME': 'HERRINGTON MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Clarithromycin'}
# {'PRACTICE_NAME': 'WEARSIDE MEDICAL PRACTICE - PALLION', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Salbutamol'}
# {'PRACTICE_NAME': 'HEATON MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Catheters'}
# {'PRACTICE_NAME': 'BELLINGHAM PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Doxazosin mesilate'}
# {'PRACTICE_NAME': 'THE OAKS FAMILY PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Vardenafil'}
# {'PRACTICE_NAME': 'BENTHAM ROAD HEALTH CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Lansoprazole'}
# {'PRACTICE_NAME': 'LIMEFIELD SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Loperamide hydrochloride'}
# {'PRACTICE_NAME': 'CASTLE PLACE PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Indapamide'}
# {'PRACTICE_NAME': 'THE SELE MEDICAL PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Oxycodone hydrochloride'}
# {'PRACTICE_NAME': 'SOUTHOVER MEDICAL PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Hydrocortisone'}
# {'PRACTICE_NAME': 'SPRING HALL GROUP PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Pancreatin'}
# {'PRACTICE_NAME': 'BOLTON MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Atorvastatin'}
# {'PRACTICE_NAME': 'ALNWICK MEDICAL GROUP', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Pravastatin sodium'}
# {'PRACTICE_NAME': 'MARINE MEDICAL GROUP', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Mesalazine (Systemic)'}
# {'PRACTICE_NAME': 'NEW SILKSWORTH MEDICAL PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Atenolol'}
# {'PRACTICE_NAME': 'DARWEN HEALTHLINK', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Betamethasone esters'}
# {'PRACTICE_NAME': 'STONYHILL MEDICAL PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Beclometasone dipropionate'}
# {'PRACTICE_NAME': 'COMBE COASTAL PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Fluticasone furoate (Inhalation)'}
# {'PRACTICE_NAME': 'CAEN MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Tolterodine'}
# {'PRACTICE_NAME': 'MOUNT PLEASANT HEALTH CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Sulfasalazine'}
# {'PRACTICE_NAME': 'GUIDEPOST MEDICAL GROUP', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Melatonin'}
# {'PRACTICE_NAME': 'SID VALLEY PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Rosuvastatin calcium'}
# {'PRACTICE_NAME': 'BRIDGE STREET SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Mupirocin'}
# {'PRACTICE_NAME': 'THE CRESCENT SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Alginic acid compound preparations'}
# {'PRACTICE_NAME': 'CRESCENT PROVIDENCE SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Betamethasone valerate'}
# {'PRACTICE_NAME': 'SEATON & COLYTON MEDICAL PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methylphenidate hydrochloride'}
# {'PRACTICE_NAME': 'QUEENS AVENUE SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Amoxicillin'}
# {'PRACTICE_NAME': 'SPRING HOUSE SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Morphine sulfate'}
# {'PRACTICE_NAME': 'FREMINGTON MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Emollients'}
# {'PRACTICE_NAME': "ST. LAURENCE'S MEDICAL CENTRE", 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Nortriptyline'}
# {'PRACTICE_NAME': 'CENTRAL SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Medroxyprogesterone acetate'}
# {'PRACTICE_NAME': 'SUNNYSIDE MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Sodium cromoglicate'}
# {'PRACTICE_NAME': 'CERNE ABBAS SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Quetiapine'}
# {'PRACTICE_NAME': 'ST THOMAS MEDICAL GROUP', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Calcipotriol'}
# {'PRACTICE_NAME': 'BRIDGE STREET SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Rabeprazole sodium'}
# {'PRACTICE_NAME': 'THE KIRTON LINDSEY AND SCOTTER SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Progesterone'}
# {'PRACTICE_NAME': 'PALLION FAMILY PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Vaginal Moisturisers'}
# {'PRACTICE_NAME': 'KINGSWAY SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Indapamide'}
# {'PRACTICE_NAME': 'BLOOMFIELD MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Fluorometholone'}
# {'PRACTICE_NAME': 'JOSHI NA', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Capsaicin'}
# {'PRACTICE_NAME': 'GLENROYD MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Oxycodone hydrochloride'}
# {'PRACTICE_NAME': 'PIKES LANE 1', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Estradiol'}
# {'PRACTICE_NAME': 'RIVERSIDE SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Night Drainage Bags'}
# {'PRACTICE_NAME': 'MARINE MEDICAL GROUP', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Tadalafil'}
# {'PRACTICE_NAME': 'LITTLE LEVER HEALTH CENTRE 2', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Venlafaxine'}
# {'PRACTICE_NAME': 'RUBY COUNTRY MEDICAL GROUP', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Gabapentin'}
# {'PRACTICE_NAME': 'PEEL GPS', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Enteral nutrition'}
# {'PRACTICE_NAME': 'WYCLIFFE SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Losartan potassium'}
# {'PRACTICE_NAME': 'PGPA IMPROVED ACCESS UPPER VALLEY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Naproxen'}
# {'PRACTICE_NAME': 'HALDON HOUSE SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Oestrogens conjugated'}
# {'PRACTICE_NAME': 'COMBE COASTAL PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Apixaban'}
# {'PRACTICE_NAME': 'SOUTH KING STREET MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Fluoxetine hydrochloride'}
# {'PRACTICE_NAME': 'SPRING HOUSE SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Oxybutynin'}
# {'PRACTICE_NAME': 'TREETON MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Lidocaine hydrochloride'}
# {'PRACTICE_NAME': 'MAYFLOWER MEDICAL GROUP', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Dulaglutide'}
# {'PRACTICE_NAME': 'CERNE ABBAS SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Docusate sodium'}
# {'PRACTICE_NAME': 'MOORDOWN MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Morphine sulfate'}
# {'PRACTICE_NAME': 'PELHAM MEDICAL GROUP', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Sulfasalazine'}
# {'PRACTICE_NAME': 'SPRING HALL GROUP PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Salbutamol'}
# {'PRACTICE_NAME': 'THE CENTRAL SURGERY BARTON', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Metronidazole'}
# {'PRACTICE_NAME': 'GRANGEWOOD SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Risperidone'}
# {'PRACTICE_NAME': 'NELPCT OUT OF HOURS SERVICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Cefalexin'}
# {'PRACTICE_NAME': 'SOUTH MOLTON MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Sitagliptin'}
# {'PRACTICE_NAME': 'WATERLOO MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Imipramine hydrochloride'}
# {'PRACTICE_NAME': 'JAMES FISHER MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Colecalciferol'}
# {'PRACTICE_NAME': 'COMBE COASTAL PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Fluconazole'}
# {'PRACTICE_NAME': 'WEAVER VALE PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Letrozole'}
# {'PRACTICE_NAME': 'SOUTH MOLTON MEDICAL CENTRE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Colecalciferol'}
# {'PRACTICE_NAME': 'ELSDON AVENUE SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Urine testing reagents'}
# {'PRACTICE_NAME': 'DALEFIELD SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Vitamin E'}
# {'PRACTICE_NAME': 'BRUNEL MEDICAL PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Macrogol 3350'}
# {'PRACTICE_NAME': 'PELHAM MEDICAL GROUP', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Ins degludec/liraglutide'}
# {'PRACTICE_NAME': 'CRICKETFIELD SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Propantheline bromide'}
# {'PRACTICE_NAME': 'WELL CLOSE MEDICAL GROUP', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Hyoscine butylbromide'}
# {'PRACTICE_NAME': 'THE GLEN MEDICAL GROUP', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Hydrocortisone'}
# {'PRACTICE_NAME': 'WEST TOWN SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Catheters'}
# {'PRACTICE_NAME': 'BRIDGE STREET SURGERY', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Catheters'}
# {'PRACTICE_NAME': 'KINGSTEIGNTON MEDICAL PRACTICE', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Catheters'}
# {'PRACTICE_NAME': 'ROLLE MEDICAL PARTNERSHIP', 'COUNT(CHEMICAL_SUBSTANCE_BNF_DESCR)': 1, 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Pancreatin'}
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# 6) E - Quantos prescribers foram adicionados no ultimo mês? 
from bson.int64 import Int64
from pymongo import MongoClient

#Realizando a conexão com o banco
client = MongoClient('localhost', 27017)
database = client["banco"]
collection = database["tabela1"]

#Aqui seria possivel criar uma parametrização para contemplar os diferentes meses
# Mas como foi pedido apenas referente ao ultimo mês. 
pipeline = [
    {
        u"$match": {
            u"YEAR_MONTH": Int64(202208)
        }
    }, 
    {
        u"$project": {
            u"CHEMICAL_SUBSTANCE_BNF_DESCR": u"$CHEMICAL_SUBSTANCE_BNF_DESCR",
            u"YEAR_MONTH": u"$YEAR_MONTH",
            u"_id": 0
        }
    }, 
    {
        u"$group": {
            u"_id": None,
            u"distinct": {
                u"$addToSet": u"$$ROOT"
            }
        }
    }, 
    {
        u"$unwind": {
            u"path": u"$distinct",
            u"preserveNullAndEmptyArrays": False
        }
    }, 
    {
        u"$replaceRoot": {
            u"newRoot": u"$distinct"
        }
    }
]

cursor = collection.aggregate(
    pipeline, 
    allowDiskUse = True
)
try:
    for doc in cursor:
        print(doc)
finally:
    client.close()
# Out:
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Aclidinium bromide', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Fluticasone propionate (Inhalation)', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Atenolol', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methylprednisolone acetate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Ketorolac trometamol', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Fluconazole', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Other sunscreening preparations', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Midodrine hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Eye Products', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Hydralazine hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Ospemifene', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Timothy grass pollen allergen extract', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Dimeticone (Barrier)', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Doxycycline monohydrate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Dexamfetamine sulfate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Zuclopenthixol hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Glyceryl trinitrate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Valsartan with diuretic', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Fexofenadine hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Travoprost', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Mesalazine (Systemic)', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Apomorphine hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Levodopa/carbidopa/entacapone', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Gauzes & Gauze Tissue', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Propylthiouracil', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Insulin detemir', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Temazepam', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Vardenafil', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Tars', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Digoxin', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Famotidine', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Naftidrofuryl oxalate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Pizotifen malate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Tibolone', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Vortioxetine', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Ergocalciferol', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Sildenafil (Erectile Dysfunction)', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Sitagliptin', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Paracetamol combined preparations', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Naratriptan hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Insulin glulisine', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Imiquimod', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Oestrogens conjugated', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Lisinopril with diuretic', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Diethylamine salicylate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Fluoxetine hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Brinzolamide and timolol', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Baclofen', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Peppermint oil', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Vitamin B compound', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Imipramine hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Telmisartan', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Bendroflumethiazide', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Atropine sulfate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Levetiracetam', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Glimepiride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Alverine citrate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Latanoprost', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Fentanyl', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Triptorelin acetate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Urea', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Insulin aspart', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Lymecycline', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Carbamazepine', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Clopidogrel', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Lidocaine hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Ispaghula husk', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Etonogestrel', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Flupentixol hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Emollients', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Sodium chloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Anastrozole', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Clomethiazole', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Hydrocortisone (Sodium succinate)', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Benzydamine hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Enoxaparin', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Clobetasol propionate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Prochlorperazine mesilate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Buprenorph hydrochloride/naloxone hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Betamethasone valerate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Amisulpride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Catheter Valves', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Vitamin E', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Rotigotine', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Clindamycin hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Other compound vitamin/mineral formulation preparations', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Pravastatin sodium', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Haloperidol', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Zonisamide', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Doxepin hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Cefradine', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Leuprorelin acetate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Isosorbide dinitrate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Sacubitril/valsartan', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Allopurinol', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Oral rehydration salts', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Carbomer 940/980', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Galantamine', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Prochlorperazine maleate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Metformin hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Warfarin sodium', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Trazodone hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Dalteparin sodium', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Trihexyphenidyl hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Heparinoid', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Tiotropium bromide/olodaterol', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Physical Debridement Device', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Chlordiazepoxide hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Erythromycin', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Salmeterol', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Adhesive Removers (Sprays/Liquids/Wipes)', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Biphasic insulin aspart', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Hydroxycarbamide', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Peak Flow Meters', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Permethrin', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Dihydrocodeine tartrate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Neomycin sulfate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Adapalene', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Formoterol fumarate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Other individually formulated bought in preparations', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Zinc sulfate monohydrate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Liquid paraffin', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Tafluprost and timolol', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Diclofenac sodium', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Vildagliptin', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Timolol', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Dexamethasone', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Colchicine', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Risperidone', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Ketone blood testing reagents', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Ketoconazole', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Bumetanide', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Ketoprofen', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Cinacalcet hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Losartan potassium', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Ciclesonide', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Chlorphenamine maleate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Insulin glargine', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Fluticasone furoate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Lacidipine', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Hydrogen peroxide', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Triamcinolone acetonide', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Irbesartan with diuretic', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Lansoprazole', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Ipratropium bromide', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Cetirizine hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Surgical Adhesive Tape', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Edoxaban', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Primidone', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Terbutaline sulphate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Perindopril erbumine', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Perampanel', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Cabergoline', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Quetiapine', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Brinzolamide/brimonidine', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Skin Fillers And Protectives', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Mycophenolate mofetil', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Lubricant Gels', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Empagliflozin', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Magnesium sulfate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Loratadine', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Cyclizine hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Catheter Maintenance Products', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Adhesive Discs/Rings/Pads/Plasters', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Ethosuximide', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Norethisterone', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Aluminium chloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Fluorouracil (Sunscreen)', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Lercanidipine hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Omeprazole', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Canagliflozin', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Pholcodine', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Thiamine hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Darifenacin hydrobromide', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Fludroxycortide', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Sodium fusidate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Belts', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Dabigatran etexilate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Tracheostomy & Laryngectomy Appliances', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Fluticasone propionate (Nasal)', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Ursodeoxycholic acid', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Erythromycin ethylsuccinate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Ciprofloxain/dexameth', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Pivmecillinam hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Goserelin acetate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Nicorandil', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Theophylline', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Alfacalcidol', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Torasemide', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Flecainide acetate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Oxybutynin', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Ulipristal acetate (Emergency Contraceptive)', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Mupirocin', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Insulin degludec', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Co-amilozide (Amiloride hydrochloride/hydrochlorothiazide)', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Ciclosporin', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Clonazepam', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Ascorbic acid', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Olopatadine', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Tolbutamide', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Vitamin A', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Co-careldopa (Carbidopa/levodopa)', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Ferrous sulfate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Gabapentin', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Betamethasone esters', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Acitretin', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Wound Management & Other Dressings', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Water for injection', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methocarbamol', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Acetazolamide', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Exemestane', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Loprazolam mesilate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Other vitamin B preparations', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Diazepam', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Oxazepam', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Minoxidil', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Timolol and bimatoprost', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Other food for special diet preparations', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Tranexamic acid', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Disulfiram', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Simeticone', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Tizanidine hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Metronidazole', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Co-dydramol (Dihydrocodeine/paracetamol)', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Budesonide', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Testosterone', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Risedronate sodium', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Umeclidinium bromide/vilanterol', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Menthol', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Fesoterodine fumarate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Diphenhydramine hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Sotalol hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Calcitriol', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Indacaterol/glycopyrronium', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Propafenone hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Quinine bisulfate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Itraconazole', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Rasagiline mesilate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Pressure Offloading Device', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Hydroxyzine hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Isosorbide mononitrate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Miconazole nitrate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Ticagrelor', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Quinine sulfate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Sumatriptan succinate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Nabumetone', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Hepatitis A/hepatitis B', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Naproxen', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Lamotrigine', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methotrexate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Esomeprazole', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Chlorpromazine hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Glucagon', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Entacapone', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Mebeverine hydrochloride compound preparations', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Bicalutamide', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Hypromellose', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Pramipexole', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Insulin Lispro', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Dienogest', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Felodipine', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Valproic acid', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Other colour, flavour and sweetening preparations', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Gliclazide', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Co-beneldopa (Benserazide/levodopa)', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Nitrazepam', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Doxycycline hyclate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Fluvastatin sodium', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Vitamins caps', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Nebivolol', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Piroxicam', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Estradiol valerate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Other health supplement preparations', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Ciprofibrate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Gluten free breads', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Fosfomycin trometamol', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Perindopril arginine', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Doxazosin mesilate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Enteral nutrition', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Low protein meals', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Prednisolone', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Glycopyrronium/formoterol', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Prucalopride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Venlafaxine', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Buprenorphine hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Irbesartan', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Ivermectin', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Anal Irrigation System', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Promethazine teoclate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Labetalol hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Ketotifen fumarate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Azelaic acid', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'INR blood testing reagents', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Hydroxychloroquine sulfate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Erdosteine', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Spironolactone', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Aspirin', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Cyanocobalamin', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Cyclopentolate hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Crotamiton', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Adapalene and benzoyl peroxide', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Other camouflage preparations', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Ferrous fumarate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Rabeprazole sodium', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Lisinopril', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Ganciclovir', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Sevelamer', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Clobazam', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Ileostomy Bags', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Venous Ulcer Compression System', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Sertraline hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Midazolam hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Terbinafine hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Frovatriptan', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Levocetirizine', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Metoprolol tartrate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Macrogol 3350', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Swabs', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Tetrabenazine', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Codeine phosphate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Acarbose', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Magnesium glycerophosphate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Hydrocortisone', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Tacrolimus', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Pancreatin', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Calcium acetate/magnesium carbonate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Finasteride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Clobetasone butyrate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Carmellose sodium', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Olmesartan medoxomil', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Sodium feredetate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Prednisolone sodium phosphate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Tafluprost', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Cinnarizine', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Amiloride hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Escitalopram', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Fusidic acid', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Paraffin soft white', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Captopril', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Beclometdiprop/formoterol/glycopyrronium', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Dipyridamole', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Co-codamol (Codeine phosphate/paracetamol)', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Tolterodine', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Other multivitamin preparations', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Dantrolene sodium', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Prednisolone acetate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Gluten free mixes', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Glycopyrronium bromide', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Phenobarbital', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Beclometasone dipropionate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Inhalation Solutions', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Hyetellose', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Canagliflozin/metformin', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Enalapril maleate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Ibuprofen', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Clomipramine hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Cetrimide', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Nitrofurantoin', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Rivaroxaban', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Tamsulosin and dutasteride hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Gluten free/low protein pasta', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Montelukast', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Triptorelin', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Colestyramine', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Stockinette', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Potassium permanganate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Solifenacin', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Combined ethinylestradiol 35mcg', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Oxcarbazepine', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Co-trimoxazole(Trimethoprim/sulfamethoxazole)', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Dapagliflozin', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Omega-3-acid ethyl esters', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Hyoscine butylbromide', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Rizatriptan', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Agomelatine', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Orlistat', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Mirabegron', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Lanthanum carbonate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Magnesium aspartate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Dorzolamide', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Sodium valproate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Mirtazapine', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Levomepromazine maleate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Mebendazole', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Emollient bath and shower preparations', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Citalopram hydrobromide', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Salicylic acid', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Zuclopenthixol decanoate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Aliskiren', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Glucose', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Soluble insulin (Neutral insulin)', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Buprenorphine', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Lidocaine', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Bisacodyl', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Celiprolol hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Fluorometholone', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Indapamide', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Potassium chloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Phenytoin sodium', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Azathioprine', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Morphine sulfate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Lymphoedema Garments', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Aripiprazole', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Tiotropium bromide', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Nicotine', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Colesevelam hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Fosinopril sodium', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Zolpidem tartrate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Lithium carbonate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Carbocisteine', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Pantoprazole', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Propantheline bromide', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Elastic Hosiery', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Terazosin hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Nortriptyline', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Other emollient preparations', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Hyoscine hydrobromide', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Sucralfate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Dutasteride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Indometacin', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Furosemide', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Donepezil hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Dorzolamide and timolol', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Benzoyl peroxide and clindamycin phosphate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Duloxetine hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Calcium acetate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Topiramate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Chlorhexidine gluconate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Mercaptopurine', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Salbutamol', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Amiodarone hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Cyclizine lactate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Co-tenidone (Atenolol/chlortalidone)', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Detection Sensor Interstitial Fluid/Gluc', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Naltrexone hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Buspirone hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Midazolam maleate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Anal Plugs', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Clindamycin/tretinoin', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Isophane insulin', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Clonidine hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Urinal Systems', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Hydrocort sodiumphos', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Medroxyprogesterone acetate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Fluvoxamine maleate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Indoramin', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Formoterol/glycopyrronium/budesonide', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Carbimazole', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Simvastatin and ezetimibe', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Phased formulations of ethinylestradiol', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Semaglutide', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Dimenhydrinate/cinnarizine', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Linagliptin', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Gentamicin sulfate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Urine testing reagents', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Desloratadine', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Alfuzosin hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Zolmitriptan', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Tamsulosin hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Trospium chloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Acetic acid', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Fluocinolone acetonide', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Pentoxifylline', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Simvastatin', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Sodium bicarbonate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Two Piece Ostomy Systems', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Febuxostat', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Brimonidine tartrate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Pilocarpine hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Exenatide', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Timolol and travoprost', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Etodolac', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Urostomy Bags', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Lactulose', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methadone hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Leflunomide', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Amlodipine', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Mefenamic acid', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Coal tar', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Oxycodone hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Liothyronine sodium', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Fludrocortisone acetate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Sodium picosulfate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Nefopam hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Linagliptin/metformin', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Co-amoxiclav (Amoxicillin/clavulanic acid)', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Irrigation Washout Appliances', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Pioglitazone hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Liraglutide', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Glucose blood testing reagents', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Incontinence Sheaths', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Other eye tear/lubricant/astringent preparations', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Desogestrel', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Paracetamol', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Levofloxacin', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Other Appliances', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Estradiol with progestogen', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Mebeverine hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Zopiclone', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Ranolazine', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Desmopressin acetate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Minocycline hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Olanzapine', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Zinc oxide', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Betahistine hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Carvedilol', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Colostomy Bags', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Azelastine hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Propranolol hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Clindamycin phosphate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Sodium cromoglicate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Estradiol', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Hydroxocobalamin', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Perindopril arginine with diuretic', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Co-cyprindiol (Cyprote acetate/ethinylestradiol)', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Meloxicam', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Ciprofloxacin', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Melatonin', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Oxytetracycline', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Hepatitis A', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Telmisartan with diuretic', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Cefalexin', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Docusate sodium', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Cimetidine', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Amitriptyline hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Irrigation Solutions', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Valaciclovir', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Clotrimazole', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Triptorelin embonate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Miconazole', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Tadalafil', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Suspensory Systems', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Nasal Products', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Testosterone undecanoate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Oral Film Forming Agents', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Co-amilofruse (Amiloride hydrochloride/frusemide)', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Candesartan cilexetil', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Sulfasalazine', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Diphtheria', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Tubing And Accessories', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Prasugrel', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Ibandronic acid', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Celecoxib', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Ivabradine', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Arm Sling/Bandages', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Somatropin', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Procyclidine hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Letrozole', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Vaginal Moisturisers', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Pyridostigmine bromide', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Modafinil', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Co-magaldrox (Magnesium/aluminium hydroxide)', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Lodoxamide trometamol', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Brivaracetam', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Nifedipine', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Flucloxacillin sodium', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Tramadol hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Atomoxetine hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Domperidone', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Valsartan', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Other food preparations', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Guanfacine', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Vacuum Pumps for Erectile Dysfunction', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Hyoscine', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Dosulepin hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Biphasic insulin lispro', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Acetylcysteine', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Benzalkonium chloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Verapamil hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Adhesive Dressing Remover Ster Silicone', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Diamorphine hydrochloride (Systemic)', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Bimatoprost', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Incontinence Sheath Fixing Strips & Adh', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Night Drainage Bags', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Biphasic isophane insulin', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Loperamide hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Catheters', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Azithromycin', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Sterculia', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Rifaximin', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Low protein mixes', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Diclofenac diethyl', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Metoclopramide hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Sulpiride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Diltiazem hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Alogliptin', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Colecalciferol', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Leg Bags', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Calcium carbonate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Ramipril', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Acamprosate calcium', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Ropinirole hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Nicardipine hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Aciclovir', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Deodorants', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Phosphates (Rectal)', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Cocois', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Alginic acid compound preparations', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Pregabalin', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Diclofenac potassium', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Alprostadil', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Tapentadol hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Ondansetron hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Levomepromazine hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Folic acid', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Combined ethinylestradiol 20mcg', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Dry Mouth Products', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Levobunolol hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Metformin hydrochloride/sitagliptin', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Meptazinol hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Memantine hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Estriol', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Fluticasone furoate (Inhalation)', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methyl salicylate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Rivastigmine', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Combined ethinylestradiol 30mcg', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Trimethoprim', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Aclidinium bromide/formoterol', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Medicated stockings', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Pyridoxine hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Mizolastine', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Clarithromycin', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Eplerenone', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Moxonidine', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Paroxetine hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Phenoxymethylpenicillin (Penicillin V)', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Carbomer 974P', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Amoxicillin', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Skin Protectors', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Calcipotriol', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Betamethasone sodium phosphate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Ferrous gluconate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Promethazine hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Fenofibrate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Almotriptan', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Dulaglutide', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Latanoprost and timolol', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Glycerol', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Levothyroxine sodium', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Flupentixol decanoate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Hepatitis A/typhoid vaccine', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Mycophenolic sodium', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Apixaban', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Lorazepam', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Senna', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Eslicarbazepine acetate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Methylphenidate hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Other base/diluent/suspending agent/stabiliser preparations', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Light liquid paraffin', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Tamoxifen citrate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Lacosamide', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Alendronic acid', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Hydrocortisone sodium succinate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Chloramphenicol', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Lofepramine hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Nadolol', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Riluzole', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Atorvastatin', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Other toiletry preparations', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Fluticasone propionate/azelastine hydrochloride (Nasal)', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Bezafibrate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Amantadine hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Benzoyl peroxide', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Mometasone furoate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Bisoprolol fumarate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Etoricoxib', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Xylometazoline hydrochloride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Hydrocortisone acetate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Nizatidine', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Typhoid', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Sodium fluoride', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Levonorgestrel', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Progesterone', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Lisdexamfetamine dimesylate', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Rosuvastatin calcium', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Ezetimibe', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Nystatin', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Sodium citrate (Rectal)', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Capsaicin', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Ciclosporin (Eye Anti Inflammatory)', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Umeclidinium bromide', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Adrenaline', 'YEAR_MONTH': 202208}
# {'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Brinzolamide', 'YEAR_MONTH': 202208}

# %%
# 6) F - Quais prescribers atuam em mais de uma região? 

from bson.int64 import Int64
from bson.son import SON
from pymongo import MongoClient

#Realizando a conexão com o banco
client = MongoClient('localhost', 27017)
database = client["banco"]
collection = database["tabela1"]

pipeline = [
    {
        u"$group": {
            u"_id": {
                u"PRACTICE_NAME": u"$PRACTICE_NAME"
            },
            u"COUNT(REGIONAL_OFFICE_NAME)": {
                u"$sum": 1
            }
        }
    }, 
    {
        u"$project": {
            u"PRACTICE_NAME": u"$_id.PRACTICE_NAME",
            u"COUNT(REGIONAL_OFFICE_NAME)": u"$COUNT(REGIONAL_OFFICE_NAME)",
            u"_id": 0
        }
    }, 
    {
        u"$match": {
            u"COUNT(REGIONAL_OFFICE_NAME)": {
                u"$gt": Int64(1)
            }
        }
    }, 
    {
        u"$sort": SON([ (u"COUNT(REGIONAL_OFFICE_NAME)", -1) ])
    }
]

cursor = collection.aggregate(
    pipeline, 
    allowDiskUse = True
)
try:
    for doc in cursor:
        print(doc)
finally:
    client.close()
# Out:
# {'PRACTICE_NAME': 'UNIDENTIFIED DOCTORS', 'COUNT(REGIONAL_OFFICE_NAME)': 650}
# {'PRACTICE_NAME': 'HAXBY GROUP PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 349}
# {'PRACTICE_NAME': 'ANCORA MEDICAL PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 294}
# {'PRACTICE_NAME': 'CLEE MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 279}
# {'PRACTICE_NAME': 'DINNINGTON GROUP PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 277}
# {'PRACTICE_NAME': 'WOODA SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 271}
# {'PRACTICE_NAME': 'THE CENTRAL SURGERY BARTON', 'COUNT(REGIONAL_OFFICE_NAME)': 257}
# {'PRACTICE_NAME': 'RIVERSIDE SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 228}
# {'PRACTICE_NAME': 'WINGATE MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 222}
# {'PRACTICE_NAME': 'SPRING HALL GROUP PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 218}
# {'PRACTICE_NAME': 'BEACON MEDICAL', 'COUNT(REGIONAL_OFFICE_NAME)': 213}
# {'PRACTICE_NAME': 'STOCKTON HEATH MED.CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 208}
# {'PRACTICE_NAME': 'SUNNYSIDE MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 208}
# {'PRACTICE_NAME': 'BLUNDELLSANDS SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 206}
# {'PRACTICE_NAME': 'CAMBRIDGE AVENUE MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 203}
# {'PRACTICE_NAME': 'DARTMOUTH MEDICAL PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 202}
# {'PRACTICE_NAME': 'MARKET SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 197}
# {'PRACTICE_NAME': 'THE KIRTON LINDSEY AND SCOTTER SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 185}
# {'PRACTICE_NAME': 'WINTERTON MEDICAL PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 184}
# {'PRACTICE_NAME': 'PELHAM MEDICAL GROUP', 'COUNT(REGIONAL_OFFICE_NAME)': 183}
# {'PRACTICE_NAME': 'GLOVERS LANE SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 177}
# {'PRACTICE_NAME': 'LIVERPOOL RD MEDICAL PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 172}
# {'PRACTICE_NAME': 'VALENS MEDICAL PARTNERSHIP', 'COUNT(REGIONAL_OFFICE_NAME)': 170}
# {'PRACTICE_NAME': 'BRIDGE STREET SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 169}
# {'PRACTICE_NAME': 'TRENT VIEW MEDICAL PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 169}
# {'PRACTICE_NAME': 'PEEL GPS', 'COUNT(REGIONAL_OFFICE_NAME)': 165}
# {'PRACTICE_NAME': 'SPRING TERRACE HEALTH CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 165}
# {'PRACTICE_NAME': 'THE JUNCTION SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 164}
# {'PRACTICE_NAME': 'WEAVER VALE PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 164}
# {'PRACTICE_NAME': 'VILLAGE SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 164}
# {'PRACTICE_NAME': 'TREETON MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 161}
# {'PRACTICE_NAME': 'WEST TIMPERLEY MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 160}
# {'PRACTICE_NAME': 'SHERBURN GROUP PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 157}
# {'PRACTICE_NAME': 'THE AVENUE SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 150}
# {'PRACTICE_NAME': 'FORD MEDICAL PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 147}
# {'PRACTICE_NAME': 'SWARLAND AVENUE SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 145}
# {'PRACTICE_NAME': 'RIBBLESDALE MEDICAL PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 142}
# {'PRACTICE_NAME': 'BEACON MEDICAL GROUP', 'COUNT(REGIONAL_OFFICE_NAME)': 136}
# {'PRACTICE_NAME': 'CHAPELFORD PRIMARY CARE CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 135}
# {'PRACTICE_NAME': 'KIRKBYMOORSIDE SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 131}
# {'PRACTICE_NAME': 'CLAYHILL MEDICAL PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 128}
# {'PRACTICE_NAME': "ST. LAURENCE'S MEDICAL CENTRE", 'COUNT(REGIONAL_OFFICE_NAME)': 126}
# {'PRACTICE_NAME': 'THE LYNTON PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 125}
# {'PRACTICE_NAME': 'MAYFLOWER MEDICAL GROUP', 'COUNT(REGIONAL_OFFICE_NAME)': 123}
# {'PRACTICE_NAME': 'GARDEN CITY MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 122}
# {'PRACTICE_NAME': 'THE BRIDGES MEDICAL CTR.', 'COUNT(REGIONAL_OFFICE_NAME)': 117}
# {'PRACTICE_NAME': 'PATHFIELDS MEDICAL GROUP', 'COUNT(REGIONAL_OFFICE_NAME)': 117}
# {'PRACTICE_NAME': 'AMMONITE HEALTH PARTNERSHIP', 'COUNT(REGIONAL_OFFICE_NAME)': 116}
# {'PRACTICE_NAME': 'THE OSWALD ROAD MEDICAL SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 115}
# {'PRACTICE_NAME': 'ROCHDALE ROAD MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 115}
# {'PRACTICE_NAME': 'SOUTH LAWN MEDICAL PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 114}
# {'PRACTICE_NAME': 'TOWNSIDE SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 111}
# {'PRACTICE_NAME': 'ROYAL CRESCENT SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 108}
# {'PRACTICE_NAME': 'WOODBANK SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 108}
# {'PRACTICE_NAME': 'ADELAIDE STREET SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 107}
# {'PRACTICE_NAME': 'CENTRAL SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 105}
# {'PRACTICE_NAME': 'DARWEN HEALTHLINK', 'COUNT(REGIONAL_OFFICE_NAME)': 105}
# {'PRACTICE_NAME': 'THORPE HESLEY SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 104}
# {'PRACTICE_NAME': 'SHELLEY MANOR HOLDENHURST MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 103}
# {'PRACTICE_NAME': 'PEMBROKE MEDICAL GROUP', 'COUNT(REGIONAL_OFFICE_NAME)': 102}
# {'PRACTICE_NAME': 'CHELSTON HALL SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 101}
# {'PRACTICE_NAME': 'STONYHILL MEDICAL PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 101}
# {'PRACTICE_NAME': 'KINGSWAY SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 101}
# {'PRACTICE_NAME': 'THE HIVE HEALTH CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 101}
# {'PRACTICE_NAME': 'HELMSLEY SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 100}
# {'PRACTICE_NAME': 'RAILWAY MEDICAL GROUP', 'COUNT(REGIONAL_OFFICE_NAME)': 100}
# {'PRACTICE_NAME': 'WEST TOWN SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 99}
# {'PRACTICE_NAME': 'ALNWICK MEDICAL GROUP', 'COUNT(REGIONAL_OFFICE_NAME)': 98}
# {'PRACTICE_NAME': 'BRIDGE VIEW MEDICAL GROUP', 'COUNT(REGIONAL_OFFICE_NAME)': 98}
# {'PRACTICE_NAME': 'RUBY COUNTRY MEDICAL GROUP', 'COUNT(REGIONAL_OFFICE_NAME)': 95}
# {'PRACTICE_NAME': 'COMBE COASTAL PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 95}
# {'PRACTICE_NAME': 'CHANNEL VIEW MEDICAL GROUP', 'COUNT(REGIONAL_OFFICE_NAME)': 94}
# {'PRACTICE_NAME': 'ST THOMAS MEDICAL GROUP', 'COUNT(REGIONAL_OFFICE_NAME)': 94}
# {'PRACTICE_NAME': 'MAYFIELD MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 93}
# {'PRACTICE_NAME': 'UNSWORTH GROUP PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 93}
# {'PRACTICE_NAME': 'ABBEY SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 93}
# {'PRACTICE_NAME': 'CORNER PLACE SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 93}
# {'PRACTICE_NAME': 'BRANNAM MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 92}
# {'PRACTICE_NAME': 'OKEHAMPTON MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 92}
# {'PRACTICE_NAME': 'SID VALLEY PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 91}
# {'PRACTICE_NAME': 'AMICUS HEALTH', 'COUNT(REGIONAL_OFFICE_NAME)': 91}
# {'PRACTICE_NAME': 'KEARSLEY MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 91}
# {'PRACTICE_NAME': 'WESTBOURNE MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 90}
# {'PRACTICE_NAME': 'GLENROYD MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 89}
# {'PRACTICE_NAME': 'COLLEGE SURGERY PARTNERSHIP', 'COUNT(REGIONAL_OFFICE_NAME)': 88}
# {'PRACTICE_NAME': 'KILDONAN HOUSE', 'COUNT(REGIONAL_OFFICE_NAME)': 88}
# {'PRACTICE_NAME': 'HONITON SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 88}
# {'PRACTICE_NAME': 'MIDDLETON HEALTH CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 87}
# {'PRACTICE_NAME': 'LITCHDON MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 87}
# {'PRACTICE_NAME': 'BLOOMFIELD MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 86}
# {'PRACTICE_NAME': 'COMPASS HOUSE MEDICAL CENTRES', 'COUNT(REGIONAL_OFFICE_NAME)': 85}
# {'PRACTICE_NAME': 'AXMINSTER MEDICAL PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 85}
# {'PRACTICE_NAME': 'SEATON PARK MEDICAL GROUP', 'COUNT(REGIONAL_OFFICE_NAME)': 85}
# {'PRACTICE_NAME': 'MILLFIELD MEDICAL GROUP', 'COUNT(REGIONAL_OFFICE_NAME)': 84}
# {'PRACTICE_NAME': 'STONEHILL MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 84}
# {'PRACTICE_NAME': 'WATERLOO MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 84}
# {'PRACTICE_NAME': 'PEVERELL PARK SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 84}
# {'PRACTICE_NAME': 'BOLTON COMMUNITY PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 84}
# {'PRACTICE_NAME': 'HETTON GROUP PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 84}
# {'PRACTICE_NAME': 'MARSDEN RD. HEALTH CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 84}
# {'PRACTICE_NAME': 'NEWTON DRIVE HEALTH CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 84}
# {'PRACTICE_NAME': 'NORTH SHORE SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 84}
# {'PRACTICE_NAME': 'DARWEN HEALTHCARE', 'COUNT(REGIONAL_OFFICE_NAME)': 83}
# {'PRACTICE_NAME': 'BARTON SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 83}
# {'PRACTICE_NAME': 'ROLLE MEDICAL PARTNERSHIP', 'COUNT(REGIONAL_OFFICE_NAME)': 83}
# {'PRACTICE_NAME': 'CORE CARE FAMILY PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 82}
# {'PRACTICE_NAME': 'NORTHAM SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 82}
# {'PRACTICE_NAME': 'KNOWLE HOUSE SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 82}
# {'PRACTICE_NAME': 'FARNHAM MEDICAL CTR.', 'COUNT(REGIONAL_OFFICE_NAME)': 82}
# {'PRACTICE_NAME': 'CHILCOTE PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 81}
# {'PRACTICE_NAME': 'GREASBROUGH MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 80}
# {'PRACTICE_NAME': 'GALLERIES MEDICAL PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 80}
# {'PRACTICE_NAME': 'TOPSHAM SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 79}
# {'PRACTICE_NAME': 'WYKE REGIS & LANEHOUSE MEDICAL PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 79}
# {'PRACTICE_NAME': 'THE CORNERSTONE PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 79}
# {'PRACTICE_NAME': 'THE DUNSTAN PARTNERSHIP', 'COUNT(REGIONAL_OFFICE_NAME)': 79}
# {'PRACTICE_NAME': 'DR STEPHENSON & PARTNERS', 'COUNT(REGIONAL_OFFICE_NAME)': 78}
# {'PRACTICE_NAME': 'ROBOROUGH SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 78}
# {'PRACTICE_NAME': 'ST PAULS MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 77}
# {'PRACTICE_NAME': 'QUAYSIDE MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 77}
# {'PRACTICE_NAME': 'REDLANDS PRIMARY CARE', 'COUNT(REGIONAL_OFFICE_NAME)': 76}
# {'PRACTICE_NAME': 'COLERIDGE MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 76}
# {'PRACTICE_NAME': 'SEATON & COLYTON MEDICAL PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 76}
# {'PRACTICE_NAME': 'SOUTHOVER MEDICAL PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 76}
# {'PRACTICE_NAME': 'COQUET MEDICAL GROUP', 'COUNT(REGIONAL_OFFICE_NAME)': 76}
# {'PRACTICE_NAME': 'MOUNT PLEASANT HEALTH CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 75}
# {'PRACTICE_NAME': 'ST ALBANS MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 75}
# {'PRACTICE_NAME': 'HARWOOD MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 75}
# {'PRACTICE_NAME': 'BURN BRAE MEDICAL GROUP', 'COUNT(REGIONAL_OFFICE_NAME)': 74}
# {'PRACTICE_NAME': 'BRUNEL MEDICAL PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 74}
# {'PRACTICE_NAME': 'LAYTON MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 74}
# {'PRACTICE_NAME': 'TAVYSIDE HEALTH CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 74}
# {'PRACTICE_NAME': 'ST GEORGES SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 73}
# {'PRACTICE_NAME': 'BIDEFORD MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 73}
# {'PRACTICE_NAME': 'DEERNESS PARK MEDICAL GROUP', 'COUNT(REGIONAL_OFFICE_NAME)': 73}
# {'PRACTICE_NAME': 'DR MALHOTRA & PARTNERS', 'COUNT(REGIONAL_OFFICE_NAME)': 72}
# {'PRACTICE_NAME': 'KEPIER MEDICAL PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 72}
# {'PRACTICE_NAME': 'CHURCH VIEW SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 72}
# {'PRACTICE_NAME': 'BEAUFORT ROAD SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 72}
# {'PRACTICE_NAME': 'SOUTH MOLTON MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 71}
# {'PRACTICE_NAME': 'NORTON BROOK MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 71}
# {'PRACTICE_NAME': 'FULWELL MEDICAL CENTRE,', 'COUNT(REGIONAL_OFFICE_NAME)': 71}
# {'PRACTICE_NAME': 'ROYAL MANOR HEALTH CARE', 'COUNT(REGIONAL_OFFICE_NAME)': 71}
# {'PRACTICE_NAME': 'CLEVELEYS GROUP PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 71}
# {'PRACTICE_NAME': 'MAYFIELD MEDICAL GROUP', 'COUNT(REGIONAL_OFFICE_NAME)': 71}
# {'PRACTICE_NAME': 'KINGSKERSWELL & IPPLEPEN MED PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 70}
# {'PRACTICE_NAME': 'STOKE SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 70}
# {'PRACTICE_NAME': 'BEDLINGTONSHIRE MED.GROUP', 'COUNT(REGIONAL_OFFICE_NAME)': 70}
# {'PRACTICE_NAME': 'LITTLE HARWOOD HEALTH CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 69}
# {'PRACTICE_NAME': 'WITTON MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 69}
# {'PRACTICE_NAME': 'THE GLEN MEDICAL GROUP', 'COUNT(REGIONAL_OFFICE_NAME)': 68}
# {'PRACTICE_NAME': 'WAWN STREET SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 68}
# {'PRACTICE_NAME': 'BLAKEWATER HEALTHCARE', 'COUNT(REGIONAL_OFFICE_NAME)': 68}
# {'PRACTICE_NAME': 'TALBOT MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 67}
# {'PRACTICE_NAME': 'CLAREMONT MEDICAL PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 67}
# {'PRACTICE_NAME': 'HIGHFIELD SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 67}
# {'PRACTICE_NAME': 'PINHOE SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 67}
# {'PRACTICE_NAME': 'JAMES FISHER MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 67}
# {'PRACTICE_NAME': 'ST LEONARDS PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 67}
# {'PRACTICE_NAME': 'KNIGHTS SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 66}
# {'PRACTICE_NAME': 'BOVEY TRACEY & CHUDLEIGH PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 66}
# {'PRACTICE_NAME': 'FREMINGTON MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 66}
# {'PRACTICE_NAME': 'ST NEOTS SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 66}
# {'PRACTICE_NAME': 'PIKES LANE 1', 'COUNT(REGIONAL_OFFICE_NAME)': 66}
# {'PRACTICE_NAME': 'WHITBURN SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 65}
# {'PRACTICE_NAME': 'MARINE MEDICAL GROUP', 'COUNT(REGIONAL_OFFICE_NAME)': 65}
# {'PRACTICE_NAME': 'HAPPY HOUSE SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 65}
# {'PRACTICE_NAME': 'SOUTHLANDS MEDICAL GROUP', 'COUNT(REGIONAL_OFFICE_NAME)': 65}
# {'PRACTICE_NAME': 'ST BEDE MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 65}
# {'PRACTICE_NAME': 'PALLION FAMILY PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 64}
# {'PRACTICE_NAME': 'CRICKETFIELD SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 64}
# {'PRACTICE_NAME': 'THE OAKS FAMILY PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 63}
# {'PRACTICE_NAME': 'FORGE MEDICAL PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 63}
# {'PRACTICE_NAME': 'STABLE FOLD SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 63}
# {'PRACTICE_NAME': 'THE KILLINGHOLME SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 63}
# {'PRACTICE_NAME': 'HERRINGTON MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 63}
# {'PRACTICE_NAME': 'NORTH ROAD WEST MED.CTR.', 'COUNT(REGIONAL_OFFICE_NAME)': 63}
# {'PRACTICE_NAME': 'MARTON MEDICAL PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 62}
# {'PRACTICE_NAME': 'SOUTHERNHAY HOUSE SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 62}
# {'PRACTICE_NAME': 'THE NEW CITY MEDICAL GROUP', 'COUNT(REGIONAL_OFFICE_NAME)': 62}
# {'PRACTICE_NAME': 'THE PANTON PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 62}
# {'PRACTICE_NAME': 'TRINITY MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 62}
# {'PRACTICE_NAME': 'DEAN CROSS SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 61}
# {'PRACTICE_NAME': 'KINGSTEIGNTON MEDICAL PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 61}
# {'PRACTICE_NAME': 'FRIARY HOUSE SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 61}
# {'PRACTICE_NAME': 'HOUGHTON MEDICAL GROUP,', 'COUNT(REGIONAL_OFFICE_NAME)': 61}
# {'PRACTICE_NAME': 'MANDALAY MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 61}
# {'PRACTICE_NAME': 'COLLIERY COURT MEDICAL GROUP', 'COUNT(REGIONAL_OFFICE_NAME)': 61}
# {'PRACTICE_NAME': 'OAKENHURST MEDICAL PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 61}
# {'PRACTICE_NAME': 'ALBANY SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 61}
# {'PRACTICE_NAME': 'BUDSHEAD MEDICAL PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 61}
# {'PRACTICE_NAME': 'ELM SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 61}
# {'PRACTICE_NAME': 'LISSON GROVE MEDICAL CTR.', 'COUNT(REGIONAL_OFFICE_NAME)': 61}
# {'PRACTICE_NAME': 'JOSHI NA', 'COUNT(REGIONAL_OFFICE_NAME)': 61}
# {'PRACTICE_NAME': 'SOUTHBOURNE PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 61}
# {'PRACTICE_NAME': 'PONTELAND MEDICAL GROUP', 'COUNT(REGIONAL_OFFICE_NAME)': 60}
# {'PRACTICE_NAME': 'THE CRESCENT SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 60}
# {'PRACTICE_NAME': 'UNION BRAE & NORHAM PRAC', 'COUNT(REGIONAL_OFFICE_NAME)': 60}
# {'PRACTICE_NAME': 'WYCLIFFE SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 60}
# {'PRACTICE_NAME': 'SUNDERLAND GP ALLIANCE MEDICAL PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 59}
# {'PRACTICE_NAME': 'SOUTH BRENT HEALTH CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 59}
# {'PRACTICE_NAME': 'CAEN MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 59}
# {'PRACTICE_NAME': 'GREYSTOKE SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 59}
# {'PRACTICE_NAME': 'LEATSIDE SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 59}
# {'PRACTICE_NAME': 'CROSS ROAD SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 58}
# {'PRACTICE_NAME': 'SWAN LANE MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 58}
# {'PRACTICE_NAME': 'YEALM MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 58}
# {'PRACTICE_NAME': 'FORDINGTON SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 57}
# {'PRACTICE_NAME': 'WOODLEA HOUSE SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 57}
# {'PRACTICE_NAME': 'VILLAGE MEDICAL GROUP', 'COUNT(REGIONAL_OFFICE_NAME)': 57}
# {'PRACTICE_NAME': 'CASTLE PLACE PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 57}
# {'PRACTICE_NAME': 'DEVON SQUARE SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 57}
# {'PRACTICE_NAME': 'RED HOUSE MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 56}
# {'PRACTICE_NAME': 'SHIFA SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 56}
# {'PRACTICE_NAME': 'YELVERTON SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 56}
# {'PRACTICE_NAME': 'BUDLEIGH SALTERTON MEDICAL PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 56}
# {'PRACTICE_NAME': 'NEW SILKSWORTH MEDICAL PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 56}
# {'PRACTICE_NAME': 'WENLOCK ROAD SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 55}
# {'PRACTICE_NAME': 'WALLINGBROOK HEALTH CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 55}
# {'PRACTICE_NAME': 'HALTWHISTLE MEDICAL GROUP', 'COUNT(REGIONAL_OFFICE_NAME)': 55}
# {'PRACTICE_NAME': 'DR EARNSHAW AND PARTNERS', 'COUNT(REGIONAL_OFFICE_NAME)': 54}
# {'PRACTICE_NAME': 'WESTBOURNE MEDICAL GROUP', 'COUNT(REGIONAL_OFFICE_NAME)': 54}
# {'PRACTICE_NAME': 'THE DORCHESTER RD SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 54}
# {'PRACTICE_NAME': 'WELL CLOSE MEDICAL GROUP', 'COUNT(REGIONAL_OFFICE_NAME)': 54}
# {'PRACTICE_NAME': 'GUIDEPOST MEDICAL GROUP', 'COUNT(REGIONAL_OFFICE_NAME)': 54}
# {'PRACTICE_NAME': 'WEARSIDE MEDICAL PRACTICE - PALLION', 'COUNT(REGIONAL_OFFICE_NAME)': 53}
# {'PRACTICE_NAME': 'ARNOLD MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 53}
# {'PRACTICE_NAME': 'THE GABLES MEDICAL GROUP', 'COUNT(REGIONAL_OFFICE_NAME)': 53}
# {'PRACTICE_NAME': 'LEVER CHAMBERS 2', 'COUNT(REGIONAL_OFFICE_NAME)': 53}
# {'PRACTICE_NAME': 'DENMARK ROAD MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 53}
# {'PRACTICE_NAME': 'THE BANKS & BEARWOOD MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 53}
# {'PRACTICE_NAME': 'STEPPING STONE PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 53}
# {'PRACTICE_NAME': 'ST.LEVAN SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 52}
# {'PRACTICE_NAME': 'BRAMBLEHAIES SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 52}
# {'PRACTICE_NAME': 'BLACKDOWN PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 52}
# {'PRACTICE_NAME': 'BENTHAM ROAD HEALTH CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 52}
# {'PRACTICE_NAME': 'FORUM FAMILY PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 52}
# {'PRACTICE_NAME': 'CRESCENT PROVIDENCE SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 52}
# {'PRACTICE_NAME': 'POUNDBURY DOCTORS SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 52}
# {'PRACTICE_NAME': 'HEATON MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 51}
# {'PRACTICE_NAME': 'BEAUMONT VILLA SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 51}
# {'PRACTICE_NAME': 'NEW WASHINGTON MEDICAL GROUP', 'COUNT(REGIONAL_OFFICE_NAME)': 51}
# {'PRACTICE_NAME': 'FIRST CONTACT & PC PATH', 'COUNT(REGIONAL_OFFICE_NAME)': 51}
# {'PRACTICE_NAME': 'MOORDOWN MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 51}
# {'PRACTICE_NAME': 'THE MARINE & OAKRIDGE PARTNERSHIP', 'COUNT(REGIONAL_OFFICE_NAME)': 51}
# {'PRACTICE_NAME': 'I J HEALTHCARE', 'COUNT(REGIONAL_OFFICE_NAME)': 50}
# {'PRACTICE_NAME': 'ST HELENS ROAD PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 50}
# {'PRACTICE_NAME': 'WIRRAL WIC (APH)_WIC APH', 'COUNT(REGIONAL_OFFICE_NAME)': 50}
# {'PRACTICE_NAME': 'SPRING VIEW MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 50}
# {'PRACTICE_NAME': 'SOUTHWAY SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 50}
# {'PRACTICE_NAME': 'QUEENS AVENUE SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 50}
# {'PRACTICE_NAME': 'IMPERIAL SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 50}
# {'PRACTICE_NAME': 'DALEFIELD SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 50}
# {'PRACTICE_NAME': 'SPRING HOUSE SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 49}
# {'PRACTICE_NAME': 'BRANCH END SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 49}
# {'PRACTICE_NAME': 'DEVONPORT HEALTH CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 48}
# {'PRACTICE_NAME': 'ABBEY DALE MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 48}
# {'PRACTICE_NAME': 'REDFERN HEALTH CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 48}
# {'PRACTICE_NAME': 'RAVENSWORTH SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 48}
# {'PRACTICE_NAME': "QUEEN'S MEDICAL CENTRE", 'COUNT(REGIONAL_OFFICE_NAME)': 48}
# {'PRACTICE_NAME': 'TONGE FOLD HEALTH CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 48}
# {'PRACTICE_NAME': 'MID DEVON MEDICAL PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 48}
# {'PRACTICE_NAME': 'IDE LANE SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 48}
# {'PRACTICE_NAME': 'ASHBURN MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 48}
# {'PRACTICE_NAME': 'SHANTI MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 47}
# {'PRACTICE_NAME': 'LITTLE LEVER HEALTH CENTRE 1', 'COUNT(REGIONAL_OFFICE_NAME)': 47}
# {'PRACTICE_NAME': 'CASTLE GARDENS SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 47}
# {'PRACTICE_NAME': 'TEIGN ESTUARY MEDICAL GROUP', 'COUNT(REGIONAL_OFFICE_NAME)': 47}
# {'PRACTICE_NAME': 'CORBRIDGE HEALTH CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 47}
# {'PRACTICE_NAME': 'CHERITON BISHOP SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 47}
# {'PRACTICE_NAME': 'THE PRINCE OF WALES SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 47}
# {'PRACTICE_NAME': 'CONCORD MEDICAL PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 47}
# {'PRACTICE_NAME': 'CROMPTON VIEW SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 47}
# {'PRACTICE_NAME': 'ATRIUM HEALTH CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 47}
# {'PRACTICE_NAME': 'OLD FARM SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 47}
# {'PRACTICE_NAME': 'BARNFIELD HILL SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 47}
# {'PRACTICE_NAME': 'SPRINGWELL MEDICAL GROUP', 'COUNT(REGIONAL_OFFICE_NAME)': 47}
# {'PRACTICE_NAME': 'OAKSIDE SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 46}
# {'PRACTICE_NAME': 'ISCA MEDICAL PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 46}
# {'PRACTICE_NAME': 'WESTBANK PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 46}
# {'PRACTICE_NAME': 'NETHERFIELD HOUSE', 'COUNT(REGIONAL_OFFICE_NAME)': 46}
# {'PRACTICE_NAME': 'WINTON HEALTH CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 46}
# {'PRACTICE_NAME': 'THE ROTHBURY PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 46}
# {'PRACTICE_NAME': 'WONFORD GREEN SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 46}
# {'PRACTICE_NAME': 'SOUTH KING STREET MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 46}
# {'PRACTICE_NAME': 'WHITE MEDICAL GROUP', 'COUNT(REGIONAL_OFFICE_NAME)': 45}
# {'PRACTICE_NAME': 'RIVERVIEW SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 45}
# {'PRACTICE_NAME': 'GRANGEWOOD SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 45}
# {'PRACTICE_NAME': 'ALBERT ROAD SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 45}
# {'PRACTICE_NAME': 'REDLAM SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 45}
# {'PRACTICE_NAME': 'PRIMROSE BANK MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 45}
# {'PRACTICE_NAME': 'ASHBURTON SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 45}
# {'PRACTICE_NAME': 'VILLETTE SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 44}
# {'PRACTICE_NAME': 'TORRINGTON HEALTH CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 44}
# {'PRACTICE_NAME': 'ROMAN ROAD HEALTH CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 44}
# {'PRACTICE_NAME': 'WOODBURY SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 44}
# {'PRACTICE_NAME': 'WEST HOE SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 43}
# {'PRACTICE_NAME': 'THE BROADWAY MEDICAL PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 43}
# {'PRACTICE_NAME': 'OLIVE FAMILY PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 43}
# {'PRACTICE_NAME': 'CROFT HALL MEDICAL PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 43}
# {'PRACTICE_NAME': 'BELLINGHAM PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 43}
# {'PRACTICE_NAME': 'WHIPTON SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 43}
# {'PRACTICE_NAME': 'PRUDHOE MEDICAL GROUP', 'COUNT(REGIONAL_OFFICE_NAME)': 42}
# {'PRACTICE_NAME': 'BOLTON MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 42}
# {'PRACTICE_NAME': 'HALDON HOUSE SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 42}
# {'PRACTICE_NAME': 'TOWNSEND HOUSE MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 42}
# {'PRACTICE_NAME': 'BOW MEDICAL PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 41}
# {'PRACTICE_NAME': 'BROWNHILL SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 41}
# {'PRACTICE_NAME': 'WOOLER HEALTH', 'COUNT(REGIONAL_OFFICE_NAME)': 41}
# {'PRACTICE_NAME': 'HALLIWELL SURGERY 1', 'COUNT(REGIONAL_OFFICE_NAME)': 40}
# {'PRACTICE_NAME': 'CARE UK COVENTRY OOH', 'COUNT(REGIONAL_OFFICE_NAME)': 40}
# {'PRACTICE_NAME': 'CRAMLINGTON MEDICAL GROUP', 'COUNT(REGIONAL_OFFICE_NAME)': 40}
# {'PRACTICE_NAME': 'HEAVITREE PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 40}
# {'PRACTICE_NAME': 'CORNERSTONE SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 40}
# {'PRACTICE_NAME': 'DR THORNILEY-WALKER & PARTNERS', 'COUNT(REGIONAL_OFFICE_NAME)': 40}
# {'PRACTICE_NAME': 'ELLISON VIEW SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 40}
# {'PRACTICE_NAME': 'AL FAL MEDICAL GROUP', 'COUNT(REGIONAL_OFFICE_NAME)': 40}
# {'PRACTICE_NAME': 'WILLIAM HOPWOOD STREET SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 39}
# {'PRACTICE_NAME': 'RALEIGH SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 39}
# {'PRACTICE_NAME': 'BUCKFASTLEIGH MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 38}
# {'PRACTICE_NAME': 'FARNWORTH FAMILY PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 38}
# {'PRACTICE_NAME': 'EAST WING PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 38}
# {'PRACTICE_NAME': 'CATHERINE HOUSE SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 38}
# {'PRACTICE_NAME': 'THE G.P.SUITE', 'COUNT(REGIONAL_OFFICE_NAME)': 38}
# {'PRACTICE_NAME': 'HUMSHAUGH & WARK MED GRP', 'COUNT(REGIONAL_OFFICE_NAME)': 38}
# {'PRACTICE_NAME': 'OLIVE MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 37}
# {'PRACTICE_NAME': 'HAYDON BRIDGE & ALLENDALE MEDICAL PRACT', 'COUNT(REGIONAL_OFFICE_NAME)': 36}
# {'PRACTICE_NAME': 'SUNDERLAND GP ALLIANCE SOUTH HYLTON SURG', 'COUNT(REGIONAL_OFFICE_NAME)': 36}
# {'PRACTICE_NAME': 'IMEARY STREET PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 36}
# {'PRACTICE_NAME': 'CERNE ABBAS SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 36}
# {'PRACTICE_NAME': 'FIG TREE MEDICAL PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 36}
# {'PRACTICE_NAME': 'MONKWEARMOUTH HEALTH CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 36}
# {'PRACTICE_NAME': 'BELFORD MEDICAL PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 35}
# {'PRACTICE_NAME': 'DEANE CLINIC 1', 'COUNT(REGIONAL_OFFICE_NAME)': 35}
# {'PRACTICE_NAME': 'VICTORIA MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 35}
# {'PRACTICE_NAME': 'BLACK TORRINGTON SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 35}
# {'PRACTICE_NAME': 'HALLIWELL SURGERY 3', 'COUNT(REGIONAL_OFFICE_NAME)': 35}
# {'PRACTICE_NAME': 'ST GEORGE & RIVERSIDE MEDICAL PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 35}
# {'PRACTICE_NAME': 'RIVERSDALE SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 34}
# {'PRACTICE_NAME': 'THE ALASTAIR ROSS MEDICAL PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 33}
# {'PRACTICE_NAME': 'NELPCT OUT OF HOURS SERVICE', 'COUNT(REGIONAL_OFFICE_NAME)': 33}
# {'PRACTICE_NAME': 'HYLTON MEDICAL GROUP', 'COUNT(REGIONAL_OFFICE_NAME)': 33}
# {'PRACTICE_NAME': 'WYNDHAM HOUSE SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 33}
# {'PRACTICE_NAME': 'GAS HOUSE LANE SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 32}
# {'PRACTICE_NAME': 'LITTLE LEVER HEALTH CENTRE 2', 'COUNT(REGIONAL_OFFICE_NAME)': 32}
# {'PRACTICE_NAME': 'HILL BARTON SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 32}
# {'PRACTICE_NAME': 'THE SELE MEDICAL PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 32}
# {'PRACTICE_NAME': 'LITTLEDOWN SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 31}
# {'PRACTICE_NAME': 'BOLTON GENERAL PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 31}
# {'PRACTICE_NAME': 'DEANE MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 31}
# {'PRACTICE_NAME': 'ADDICTIONS SERVICE', 'COUNT(REGIONAL_OFFICE_NAME)': 31}
# {'PRACTICE_NAME': 'WYRESDALE ROAD SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 31}
# {'PRACTICE_NAME': 'MODBURY HEALTH CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 30}
# {'PRACTICE_NAME': 'PARK LANE PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 30}
# {'PRACTICE_NAME': 'HALLIWELL SURGERY 2', 'COUNT(REGIONAL_OFFICE_NAME)': 30}
# {'PRACTICE_NAME': 'GREAT LEVER ONE', 'COUNT(REGIONAL_OFFICE_NAME)': 29}
# {'PRACTICE_NAME': 'ORIENT HOUSE MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 29}
# {'PRACTICE_NAME': 'BRADFORD STREET SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 29}
# {'PRACTICE_NAME': 'BLACKPOOL LOCALITY CHS', 'COUNT(REGIONAL_OFFICE_NAME)': 28}
# {'PRACTICE_NAME': 'HOLLINS GROVE SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 28}
# {'PRACTICE_NAME': 'FAMILY PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 28}
# {'PRACTICE_NAME': 'MALTHOUSE MEADOWS SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 28}
# {'PRACTICE_NAME': 'NORTHUMBERLAND HEALTH', 'COUNT(REGIONAL_OFFICE_NAME)': 28}
# {'PRACTICE_NAME': 'PUDDLETOWN SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 28}
# {'PRACTICE_NAME': 'CHAGFORD HEALTH CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 27}
# {'PRACTICE_NAME': 'WEMBURY SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 27}
# {'PRACTICE_NAME': 'CASTLETOWN MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 27}
# {'PRACTICE_NAME': 'LIMEFIELD SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 27}
# {'PRACTICE_NAME': 'MORETONHAMPSTEAD HEALTH CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 26}
# {'PRACTICE_NAME': 'DR M DAKSHINA-MURTHI', 'COUNT(REGIONAL_OFFICE_NAME)': 26}
# {'PRACTICE_NAME': 'CRANBROOK MEDICAL PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 25}
# {'PRACTICE_NAME': 'CHILLINGTON HEALTH CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 25}
# {'PRACTICE_NAME': 'ELSDON AVENUE SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 25}
# {'PRACTICE_NAME': 'WE ARE WITH YOU NORTH LINCOLNSHIRE', 'COUNT(REGIONAL_OFFICE_NAME)': 25}
# {'PRACTICE_NAME': 'CLOCK TOWER SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 25}
# {'PRACTICE_NAME': 'THE ADDERLANE SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 25}
# {'PRACTICE_NAME': 'BRADWORTHY SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 24}
# {'PRACTICE_NAME': 'WEST VIEW SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 24}
# {'PRACTICE_NAME': 'DEVON DOCTORS ON CALL OOH', 'COUNT(REGIONAL_OFFICE_NAME)': 24}
# {'PRACTICE_NAME': 'CARE PLUS GROUP', 'COUNT(REGIONAL_OFFICE_NAME)': 23}
# {'PRACTICE_NAME': 'TURNING POINT - HEREFORDSHIRE', 'COUNT(REGIONAL_OFFICE_NAME)': 23}
# {'PRACTICE_NAME': 'SPRING-FENISCO HEALTHLINK', 'COUNT(REGIONAL_OFFICE_NAME)': 23}
# {'PRACTICE_NAME': 'CHESTER SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 23}
# {'PRACTICE_NAME': 'LYNTON HEALTH CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 21}
# {'PRACTICE_NAME': 'FOXHAYES PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 21}
# {'PRACTICE_NAME': 'BEEHIVE SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 20}
# {'PRACTICE_NAME': 'HARTLAND SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 20}
# {'PRACTICE_NAME': 'BURNSIDE SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 19}
# {'PRACTICE_NAME': 'URGENT CARE', 'COUNT(REGIONAL_OFFICE_NAME)': 18}
# {'PRACTICE_NAME': 'CGL EAST CHESHIRE', 'COUNT(REGIONAL_OFFICE_NAME)': 18}
# {'PRACTICE_NAME': 'WE ARE WITH YOU NORTH EAST LINCOLNSHIRE', 'COUNT(REGIONAL_OFFICE_NAME)': 18}
# {'PRACTICE_NAME': 'CHARLOTTE STREET SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 18}
# {'PRACTICE_NAME': 'NOTTINGHAM NHS URGENT CARE CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 17}
# {'PRACTICE_NAME': 'FORWARD LEEDS', 'COUNT(REGIONAL_OFFICE_NAME)': 17}
# {'PRACTICE_NAME': 'RICKLETON MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 16}
# {'PRACTICE_NAME': 'GLOUCESTER (CARE UK) OOH', 'COUNT(REGIONAL_OFFICE_NAME)': 15}
# {'PRACTICE_NAME': 'NDUC NORTHUMBERLAND OOH', 'COUNT(REGIONAL_OFFICE_NAME)': 15}
# {'PRACTICE_NAME': 'SAMPFORD PEVERELL SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 15}
# {'PRACTICE_NAME': 'SCOTS GAP MEDICAL GROUP', 'COUNT(REGIONAL_OFFICE_NAME)': 15}
# {'PRACTICE_NAME': 'NORTH LINCS DERMATOLOGY SERVICE', 'COUNT(REGIONAL_OFFICE_NAME)': 14}
# {'PRACTICE_NAME': 'EXTENDED ACCESS HUB', 'COUNT(REGIONAL_OFFICE_NAME)': 14}
# {'PRACTICE_NAME': '3D MEDICAL CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 14}
# {'PRACTICE_NAME': 'BUCKLAND SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 14}
# {'PRACTICE_NAME': 'GTD HEALTHCARE CHORLEY OOH', 'COUNT(REGIONAL_OFFICE_NAME)': 13}
# {'PRACTICE_NAME': 'COMMUNITY SUBSTANCE MISUSE TEAM', 'COUNT(REGIONAL_OFFICE_NAME)': 13}
# {'PRACTICE_NAME': 'CGL BIRMINGHAM SOUTH', 'COUNT(REGIONAL_OFFICE_NAME)': 13}
# {'PRACTICE_NAME': 'RDASH NTH LINCS COMMUNITY MH SERVICE', 'COUNT(REGIONAL_OFFICE_NAME)': 13}
# {'PRACTICE_NAME': 'NL EXTENDED ACCESS', 'COUNT(REGIONAL_OFFICE_NAME)': 12}
# {'PRACTICE_NAME': 'URGENT CARE CTR (FCMS) OOH', 'COUNT(REGIONAL_OFFICE_NAME)': 12}
# {'PRACTICE_NAME': 'COMPASS MEDICAL PRACTICE', 'COUNT(REGIONAL_OFFICE_NAME)': 11}
# {'PRACTICE_NAME': 'CGL CAMBRIDGESHIRE', 'COUNT(REGIONAL_OFFICE_NAME)': 11}
# {'PRACTICE_NAME': 'GP LED HEALTH CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 11}
# {'PRACTICE_NAME': 'STAFFORDSHIRE TREATMENT&RECOVERY SERVICE', 'COUNT(REGIONAL_OFFICE_NAME)': 11}
# {'PRACTICE_NAME': 'PENNINE CARE', 'COUNT(REGIONAL_OFFICE_NAME)': 11}
# {'PRACTICE_NAME': 'PRIMARY CARE DRUGS SERVICE', 'COUNT(REGIONAL_OFFICE_NAME)': 11}
# {'PRACTICE_NAME': 'WE ARE WITH YOU CORNWALL CENTRAL', 'COUNT(REGIONAL_OFFICE_NAME)': 11}
# {'PRACTICE_NAME': 'GTD HEALTHCARE PRESTON OOH', 'COUNT(REGIONAL_OFFICE_NAME)': 11}
# {'PRACTICE_NAME': 'WARWICKSHIRE GP OOH', 'COUNT(REGIONAL_OFFICE_NAME)': 11}
# {'PRACTICE_NAME': 'CGL NORFOLK', 'COUNT(REGIONAL_OFFICE_NAME)': 10}
# {'PRACTICE_NAME': 'MIDAS', 'COUNT(REGIONAL_OFFICE_NAME)': 10}
# {'PRACTICE_NAME': 'NORTH EAST LINCOLNSHIRE DERMATOLOGY', 'COUNT(REGIONAL_OFFICE_NAME)': 10}
# {'PRACTICE_NAME': 'B&H EXTENDED HOURS SERVICE', 'COUNT(REGIONAL_OFFICE_NAME)': 10}
# {'PRACTICE_NAME': 'GP HEALTHCARE ALLIANCE - ASHINGDON', 'COUNT(REGIONAL_OFFICE_NAME)': 10}
# {'PRACTICE_NAME': 'ROCHDALE AND OLDHAM ACTIVE RECOVERY', 'COUNT(REGIONAL_OFFICE_NAME)': 10}
# {'PRACTICE_NAME': 'BRADFORD NEW DIRECTIONS', 'COUNT(REGIONAL_OFFICE_NAME)': 10}
# {'PRACTICE_NAME': 'TORBAY AND SOUTHERN DHCT', 'COUNT(REGIONAL_OFFICE_NAME)': 10}
# {'PRACTICE_NAME': 'WARWICKSHIRE DRUG & ALCOHOL RECOVERY', 'COUNT(REGIONAL_OFFICE_NAME)': 9}
# {'PRACTICE_NAME': 'STAR - EAST SUSSEX DRUG & ALCOHOL SERV', 'COUNT(REGIONAL_OFFICE_NAME)': 9}
# {'PRACTICE_NAME': 'STAMFORD OOH', 'COUNT(REGIONAL_OFFICE_NAME)': 9}
# {'PRACTICE_NAME': 'CPT WORTHING', 'COUNT(REGIONAL_OFFICE_NAME)': 9}
# {'PRACTICE_NAME': 'CGL KIRKLEES', 'COUNT(REGIONAL_OFFICE_NAME)': 9}
# {'PRACTICE_NAME': 'SUNDERLAND EXTENDED ACCESS SERVICE', 'COUNT(REGIONAL_OFFICE_NAME)': 9}
# {'PRACTICE_NAME': 'CGL WIRRAL', 'COUNT(REGIONAL_OFFICE_NAME)': 9}
# {'PRACTICE_NAME': 'CARE UK OOH', 'COUNT(REGIONAL_OFFICE_NAME)': 9}
# {'PRACTICE_NAME': 'TURNING POINT LEICESTERSHRE COUNTY', 'COUNT(REGIONAL_OFFICE_NAME)': 9}
# {'PRACTICE_NAME': 'COMMUNITY DERMATOLOGY SERVICE', 'COUNT(REGIONAL_OFFICE_NAME)': 9}
# {'PRACTICE_NAME': 'GLOUCESTERSHIRE DRUG & ALCOHOL RECOVERY', 'COUNT(REGIONAL_OFFICE_NAME)': 8}
# {'PRACTICE_NAME': 'BLACKPOOL SUBSTANCE MISUSE SERVICE', 'COUNT(REGIONAL_OFFICE_NAME)': 8}
# {'PRACTICE_NAME': 'OXFORDSHIRE ROADS TO RECOVERY', 'COUNT(REGIONAL_OFFICE_NAME)': 8}
# {'PRACTICE_NAME': 'CGL-NEWHAM RISE', 'COUNT(REGIONAL_OFFICE_NAME)': 8}
# {'PRACTICE_NAME': 'INSPIRING RECOVERY - WAKEFIELD', 'COUNT(REGIONAL_OFFICE_NAME)': 8}
# {'PRACTICE_NAME': 'CGL TOWER HAMLETS', 'COUNT(REGIONAL_OFFICE_NAME)': 8}
# {'PRACTICE_NAME': 'PRACTICE PLUS GROUP OOH', 'COUNT(REGIONAL_OFFICE_NAME)': 8}
# {'PRACTICE_NAME': 'NMS CGL NOTTINGHAMSHIRE', 'COUNT(REGIONAL_OFFICE_NAME)': 8}
# {'PRACTICE_NAME': 'GRANTHAM OOHS', 'COUNT(REGIONAL_OFFICE_NAME)': 8}
# {'PRACTICE_NAME': 'CRANSTOUN WORCESTERSHIRE', 'COUNT(REGIONAL_OFFICE_NAME)': 7}
# {'PRACTICE_NAME': 'CLEVEDON MINOR INJURY UNIT', 'COUNT(REGIONAL_OFFICE_NAME)': 7}
# {'PRACTICE_NAME': 'CGL NORTH & CENTRAL LANCASHIRE', 'COUNT(REGIONAL_OFFICE_NAME)': 7}
# {'PRACTICE_NAME': 'CSRPRESTON COMMUNITY DERMATOLOGY SERVICE', 'COUNT(REGIONAL_OFFICE_NAME)': 7}
# {'PRACTICE_NAME': 'ABH MANCHESTER & TRAFFORD CDS', 'COUNT(REGIONAL_OFFICE_NAME)': 7}
# {'PRACTICE_NAME': 'DERMATOLOGY TIER TWO SERVICE', 'COUNT(REGIONAL_OFFICE_NAME)': 7}
# {'PRACTICE_NAME': 'SOUTHEND TREATMENT AND RECOVERY SERVICE', 'COUNT(REGIONAL_OFFICE_NAME)': 7}
# {'PRACTICE_NAME': 'WE ARE WITH YOU SHROPSHIRE', 'COUNT(REGIONAL_OFFICE_NAME)': 7}
# {'PRACTICE_NAME': 'EAST KENT DRUG AND ALCOHOL SERVICE', 'COUNT(REGIONAL_OFFICE_NAME)': 7}
# {'PRACTICE_NAME': 'CGL TAMESIDE', 'COUNT(REGIONAL_OFFICE_NAME)': 7}
# {'PRACTICE_NAME': 'CGL SOUTHWARK', 'COUNT(REGIONAL_OFFICE_NAME)': 7}
# {'PRACTICE_NAME': 'GP APH OOH', 'COUNT(REGIONAL_OFFICE_NAME)': 7}
# {'PRACTICE_NAME': 'SPECTRUM', 'COUNT(REGIONAL_OFFICE_NAME)': 7}
# {'PRACTICE_NAME': 'TURNING POINT - H&CRS (HACKNEY)', 'COUNT(REGIONAL_OFFICE_NAME)': 7}
# {'PRACTICE_NAME': 'START', 'COUNT(REGIONAL_OFFICE_NAME)': 6}
# {'PRACTICE_NAME': 'PRINGLE STREET SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 6}
# {'PRACTICE_NAME': 'CGL BRIGHTON & HOVE', 'COUNT(REGIONAL_OFFICE_NAME)': 6}
# {'PRACTICE_NAME': 'PGPA IMPROVED ACCESS UPPER VALLEY', 'COUNT(REGIONAL_OFFICE_NAME)': 6}
# {'PRACTICE_NAME': 'PSYCHIATRY-UK', 'COUNT(REGIONAL_OFFICE_NAME)': 6}
# {'PRACTICE_NAME': 'COMMUNITY GERIATRICIANS', 'COUNT(REGIONAL_OFFICE_NAME)': 6}
# {'PRACTICE_NAME': 'WEST KENT RECOVERY SERVICE', 'COUNT(REGIONAL_OFFICE_NAME)': 6}
# {'PRACTICE_NAME': 'CHEVIOT MEDICAL GROUP', 'COUNT(REGIONAL_OFFICE_NAME)': 6}
# {'PRACTICE_NAME': 'WE ARE WITH YOU REDCAR&CLEVELAND-STH BNK', 'COUNT(REGIONAL_OFFICE_NAME)': 6}
# {'PRACTICE_NAME': 'CGL HAVERING', 'COUNT(REGIONAL_OFFICE_NAME)': 6}
# {'PRACTICE_NAME': 'SOUTH TYNESIDE & SUNDERLAND NHS FT SUN', 'COUNT(REGIONAL_OFFICE_NAME)': 6}
# {'PRACTICE_NAME': 'WEEKEND SERVICE OOH', 'COUNT(REGIONAL_OFFICE_NAME)': 5}
# {'PRACTICE_NAME': 'INSPIRE CGL', 'COUNT(REGIONAL_OFFICE_NAME)': 5}
# {'PRACTICE_NAME': 'CGL RESOLUTIONS SERVICE', 'COUNT(REGIONAL_OFFICE_NAME)': 5}
# {'PRACTICE_NAME': 'CALDERDALE RECOVERY STEPS', 'COUNT(REGIONAL_OFFICE_NAME)': 5}
# {'PRACTICE_NAME': 'THE BEACON INTERMEDIATE CARE', 'COUNT(REGIONAL_OFFICE_NAME)': 5}
# {'PRACTICE_NAME': 'FELTON SURGERY', 'COUNT(REGIONAL_OFFICE_NAME)': 5}
# {'PRACTICE_NAME': 'RECOVERY STEPS CUMBRIA', 'COUNT(REGIONAL_OFFICE_NAME)': 5}
# {'PRACTICE_NAME': 'SOUTHAMPTON DRUG & ALCOHOL SERVICES', 'COUNT(REGIONAL_OFFICE_NAME)': 5}
# {'PRACTICE_NAME': 'FRESHNEY PELHAM CARE LIMITED', 'COUNT(REGIONAL_OFFICE_NAME)': 4}
# {'PRACTICE_NAME': 'HAMMERSMITH AND FULHAM DAWS', 'COUNT(REGIONAL_OFFICE_NAME)': 4}
# {'PRACTICE_NAME': 'CHILD & ADOLESCENT MENTAL HEALTH SERVICE', 'COUNT(REGIONAL_OFFICE_NAME)': 4}
# {'PRACTICE_NAME': 'CGL ASPIRE', 'COUNT(REGIONAL_OFFICE_NAME)': 4}
# {'PRACTICE_NAME': 'SOUTHAMPTON MINOR INJURIES UNIT', 'COUNT(REGIONAL_OFFICE_NAME)': 4}
# {'PRACTICE_NAME': 'ICAR', 'COUNT(REGIONAL_OFFICE_NAME)': 4}
# {'PRACTICE_NAME': 'LCFT NMPS', 'COUNT(REGIONAL_OFFICE_NAME)': 4}
# {'PRACTICE_NAME': 'PLYMOUTH SPECIALIST ADDICTION SERVICE', 'COUNT(REGIONAL_OFFICE_NAME)': 4}
# {'PRACTICE_NAME': 'TURNING POINT MEDWAY', 'COUNT(REGIONAL_OFFICE_NAME)': 4}
# {'PRACTICE_NAME': 'CGL CROYDON SMS', 'COUNT(REGIONAL_OFFICE_NAME)': 4}
# {'PRACTICE_NAME': 'OLDER PEOPLES MENTAL HEALTH', 'COUNT(REGIONAL_OFFICE_NAME)': 4}
# {'PRACTICE_NAME': 'ISLE OF WIGHT NHS TRUST NMP', 'COUNT(REGIONAL_OFFICE_NAME)': 4}
# {'PRACTICE_NAME': "ST MARY'S HOSPITAL UCC", 'COUNT(REGIONAL_OFFICE_NAME)': 4}
# {'PRACTICE_NAME': 'SOUTH TYNESIDE ENHANCED PRIMARY CARE', 'COUNT(REGIONAL_OFFICE_NAME)': 4}
# {'PRACTICE_NAME': 'WESTMINSTER DAWS', 'COUNT(REGIONAL_OFFICE_NAME)': 4}
# {'PRACTICE_NAME': 'BARDOC GP OOH', 'COUNT(REGIONAL_OFFICE_NAME)': 4}
# {'PRACTICE_NAME': 'CGL SERVICES', 'COUNT(REGIONAL_OFFICE_NAME)': 4}
# {'PRACTICE_NAME': 'HEREFORDSHIRE MH COMMUNITY WAA', 'COUNT(REGIONAL_OFFICE_NAME)': 4}
# {'PRACTICE_NAME': 'WE ARE WITH YOU IN BCP', 'COUNT(REGIONAL_OFFICE_NAME)': 4}
# {'PRACTICE_NAME': 'WIGAN CAMHS', 'COUNT(REGIONAL_OFFICE_NAME)': 3}
# {'PRACTICE_NAME': 'WOODSPRING LOCALITY', 'COUNT(REGIONAL_OFFICE_NAME)': 3}
# {'PRACTICE_NAME': 'SOUTH TYNESIDE & SUNDERLAND NHS FT STY', 'COUNT(REGIONAL_OFFICE_NAME)': 3}
# {'PRACTICE_NAME': 'ACUTE MENTAL HEALTH', 'COUNT(REGIONAL_OFFICE_NAME)': 3}
# {'PRACTICE_NAME': 'NDUC GP OUT OF HOURS SERVICE (OOH)', 'COUNT(REGIONAL_OFFICE_NAME)': 3}
# {'PRACTICE_NAME': 'ADULT ADHD SERVICE', 'COUNT(REGIONAL_OFFICE_NAME)': 3}
# {'PRACTICE_NAME': 'CIRCLE INTEGRATED CARE', 'COUNT(REGIONAL_OFFICE_NAME)': 3}
# {'PRACTICE_NAME': 'LIVEWELL S/W', 'COUNT(REGIONAL_OFFICE_NAME)': 3}
# {'PRACTICE_NAME': 'BURY ST EDMUNDS-SUFFOLK RECOVERY SERVICE', 'COUNT(REGIONAL_OFFICE_NAME)': 3}
# {'PRACTICE_NAME': 'BHR COMMUNITY ENT SERVICE', 'COUNT(REGIONAL_OFFICE_NAME)': 3}
# {'PRACTICE_NAME': 'CMHS CUMBERLAND', 'COUNT(REGIONAL_OFFICE_NAME)': 3}
# {'PRACTICE_NAME': 'SUFFOLK RECOVERY SERVICE - LOWESTOFT', 'COUNT(REGIONAL_OFFICE_NAME)': 3}
# {'PRACTICE_NAME': 'NORTHUMBERLAND CHILD HEALTH CENTRE', 'COUNT(REGIONAL_OFFICE_NAME)': 3}
# {'PRACTICE_NAME': 'TURNING POINT SOMERSET', 'COUNT(REGIONAL_OFFICE_NAME)': 3}
# {'PRACTICE_NAME': 'GAINSBOROUGH UTC', 'COUNT(REGIONAL_OFFICE_NAME)': 3}
# {'PRACTICE_NAME': 'WIRRAL HEART SUPPORT', 'COUNT(REGIONAL_OFFICE_NAME)': 3}
# {'PRACTICE_NAME': 'CRANSTOUN SANDWELL', 'COUNT(REGIONAL_OFFICE_NAME)': 3}
# {'PRACTICE_NAME': 'CRANSTOUN WOKINGHAM', 'COUNT(REGIONAL_OFFICE_NAME)': 3}
# {'PRACTICE_NAME': 'HEART FAILURE TIER TWO SERVICE', 'COUNT(REGIONAL_OFFICE_NAME)': 3}
# {'PRACTICE_NAME': 'MACMILLAN ST HELENS SP, PALLIATIVE CARE', 'COUNT(REGIONAL_OFFICE_NAME)': 3}
# {'PRACTICE_NAME': 'TORBAY NMP SPECIALIST', 'COUNT(REGIONAL_OFFICE_NAME)': 3}
# {'PRACTICE_NAME': 'NEWMEDICA COMMUNITY OPHTHALMOLOGY', 'COUNT(REGIONAL_OFFICE_NAME)': 3}
# {'PRACTICE_NAME': 'HEREFORDSHIRE MH ACUTE WAA', 'COUNT(REGIONAL_OFFICE_NAME)': 3}
# {'PRACTICE_NAME': 'COMMUNITY PAEDIATRICIANS', 'COUNT(REGIONAL_OFFICE_NAME)': 3}
# {'PRACTICE_NAME': 'TURNING POINT LEICESTER CITY', 'COUNT(REGIONAL_OFFICE_NAME)': 2}
# {'PRACTICE_NAME': 'SUFFOLK RECOVERY SERVICE - IPSWICH', 'COUNT(REGIONAL_OFFICE_NAME)': 2}
# {'PRACTICE_NAME': 'CGL BARNET', 'COUNT(REGIONAL_OFFICE_NAME)': 2}
# {'PRACTICE_NAME': 'TURNING POINT - H&CRS (CITY OF LONDON)', 'COUNT(REGIONAL_OFFICE_NAME)': 2}
# {'PRACTICE_NAME': 'CGL WALTHAM FOREST', 'COUNT(REGIONAL_OFFICE_NAME)': 2}
# {'PRACTICE_NAME': 'LOCAL PRIMARY CARE NORTH LOCALITY SPOKE', 'COUNT(REGIONAL_OFFICE_NAME)': 2}
# {'PRACTICE_NAME': 'PRACTICE PLUS GRP HOSP SHEPTON MALLET', 'COUNT(REGIONAL_OFFICE_NAME)': 2}
# {'PRACTICE_NAME': 'COVENTRY SMS', 'COUNT(REGIONAL_OFFICE_NAME)': 2}
# {'PRACTICE_NAME': 'SEXUAL HEALTH WIRRAL', 'COUNT(REGIONAL_OFFICE_NAME)': 2}
# {'PRACTICE_NAME': 'CRI CAMDEN COMMUNITY DRUG TREATMENT SERV', 'COUNT(REGIONAL_OFFICE_NAME)': 2}
# {'PRACTICE_NAME': 'ABOUT HEALTH LTD', 'COUNT(REGIONAL_OFFICE_NAME)': 2}
# {'PRACTICE_NAME': 'WE ARE WITH YOU REDCAR&CLEVELAND-REDCAR', 'COUNT(REGIONAL_OFFICE_NAME)': 2}
# {'PRACTICE_NAME': 'FARMBOROUGH COURT', 'COUNT(REGIONAL_OFFICE_NAME)': 2}
# {'PRACTICE_NAME': 'ROWCROFT COMMUNITY SERVICES', 'COUNT(REGIONAL_OFFICE_NAME)': 2}
# {'PRACTICE_NAME': 'HAVEN COURT', 'COUNT(REGIONAL_OFFICE_NAME)': 2}
# {'PRACTICE_NAME': 'SOUTH TYNESIDE URGENT CARE HUB WIC', 'COUNT(REGIONAL_OFFICE_NAME)': 2}
# {'PRACTICE_NAME': 'BMI BEAUMONT HOSPITAL', 'COUNT(REGIONAL_OFFICE_NAME)': 2}

# %%
# 6) G - Qual o preço médio dos químicos prescritos em no ultimo mês coletado?

from bson.int64 import Int64
from pymongo import MongoClient

#Realizando a conexão com o Banco
client = MongoClient('localhost', 27017)
database = client["banco"]
collection = database["tabela1"]

print("Mês - 08")
pipeline = [
    {
        u"$match": {
            u"YEAR_MONTH": Int64(202208)
        }
    }, 
    {
        u"$group": {
            u"_id": {},
            u"AVG(ACTUAL_COST)": {
                u"$avg": u"$ACTUAL_COST"
            }
        }
    }, 
    {
        u"$project": {
            u"AVG(ACTUAL_COST)": u"$AVG(ACTUAL_COST)",
            u"_id": 0
        }
    }
]

cursor = collection.aggregate(
    pipeline, 
    allowDiskUse = True
)
try:
    for doc in cursor:
        print(doc)
finally:
    client.close()
# Out:
# Mês - 08
# {'AVG(ACTUAL_COST)': 48.528128153}

# %%
# G) H - Gere uma tabela que contenha apenas a prescrição de maior valor de cada usuário.
# Nesse exercício não foi possivel entender o que o enunciado quis dizer com o usuário
